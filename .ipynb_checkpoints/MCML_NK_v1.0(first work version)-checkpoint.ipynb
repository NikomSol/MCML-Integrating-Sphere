# %%
import numpy as np 
from numba import jit

import matplotlib.pyplot as plt
# %matplotlib notebook

import cProfile
#@jit(nopython=True)

# %%
# supporting function

# def gauss(A=1, w=10**-3, x0=0, y0=0):
#     return lambda x,y: A*np.exp(-((x-x0)**2 + (y-y0)**2)/w**2)

@jit(nopython=True)
def gen_gauss(r0, r1, w=10**-3, x0=0, y0=0):
    ph = 2*np.pi*r0
    radius = w*np.sqrt(-np.log(r1))
    return x0 + np.cos(ph) * radius, y0 + np.sin(ph) * radius

@jit(nopython=True)
def gen_cyrcle(r0, r1, w=10**-3, x0=0, y0=0):
    ph = 2*np.pi*r0
    radius = w*r1
    return x0 + np.cos(ph) * radius, y0 + np.sin(ph) * radius

@jit(nopython=True)
def generator(generator_distribution, n, radiation_output):
    p = np.zeros(8)
    
    # coordinate and angulary distribution
    if generator_distribution == 'Gauss':
        p[0], p[1] = gen_gauss(np.random.random(1)[0],np.random.random(1)[0])
        p[5] = 1
    elif generator_distribution == 'Cyrcle':
        p[0], p[1] = gen_cyrcle(np.random.random(1)[0],np.random.random(1)[0])
        p[5] = 1
    else:
        p[5] = 1

    # start mass with frenel reflection
    r = R_frenel(np.arccos(p[5]), 1, n)
    p[6] = 1 - r
    
    # start layer
    p[7] = 0
    
    # collimated reflection radiation record
    if len(radiation_output) == 4:
        radiation_output[-1] += r
    
    return p

@jit(nopython=True)
def turn(old_p, g):
    p = old_p * 1.
    th = np.arccos(1/2/g*(1+g**2-((1-g**2)/(1-g+2*g*np.random.random(1)[0]))**2))
    ph = 2*np.pi*np.random.random(1)[0]
    
    sin_th = np.sin(th)
    cos_th = np.cos(th)
    sin_ph = np.sin(ph)
    cos_ph = np.cos(ph)
    
    if p[5] != 1. and p[5] != -1.:
        cx = (sin_th*(p[3]*p[5]*cos_ph-p[4]*sin_ph))/(np.sqrt(1-p[5]**2))+p[3]*cos_th
        cy = (sin_th*(p[4]*p[5]*cos_ph+p[3]*sin_ph))/(np.sqrt(1-p[5]**2))+p[4]*cos_th
        cz = -(np.sqrt(1-p[5]**2))*sin_th*cos_ph+p[5]*cos_th
    if p[5] == 1.:
        cx = sin_th*cos_ph
        cy = sin_th*sin_ph
        cz = cos_th
    if p[5] == -1.:
        cx = sin_th*cos_ph
        cy = -sin_th*sin_ph
        cz = -cos_th
    
    p[3], p[4], p[5] = cx, cy, cz
    
    return p

@jit(nopython=True)
def term(old_p):
    p = old_p * 1.
    threshold_m = 10**-4
    threshold_factor = 10
    if (p[6] < threshold_m) & (p[6] != 0.):
        if np.random.random(1)[0]<=1/threshold_factor:
            p[6] = threshold_m * threshold_factor
        else:
            p[6] = 0.
    return p

@jit(nopython=True)
def reflection(old_p, n_table):
    p = old_p * 1.
    layer_number = len(n_table)
    layer_index = int(p[-1])
    n1 = n_table[layer_index]
    
    if (layer_index == layer_number - 1) and (p[5] > 0):
        n2 = 1
        buf = -2
    elif (layer_index != layer_number - 1) and (p[5] > 0):
        n2 = n_table[layer_index + 1]
        buf = layer_index + 1
    elif (layer_index == 0) and (p[5] < 0):
        n2 = 1 
        buf = -1
    else:
        n2 = n_table[layer_index - 1]
        buf = layer_index - 1
    
    if np.random.random(1)[0] < R_frenel(np.arccos(p[5]), n1,n2):
        p[5] = -p[5]
    else:
        p[5] = np.sqrt(1 - (n1/n2)**2 * (1 - p[5]**2)) * np.sign(p[5])
        p[-1] = buf
        
    return p
        
@jit(nopython=True)
def R_frenel(th, n1,n2):
    if th>np.pi/2:
        th = np.pi-th
    
    n = n1/n2
    cos_th1 = np.cos(th)
    cos_th2 = np.cos(np.arcsin(n*np.sin(th)))
    
    def rs(cos_th1, cos_th2, n1, n2):
        a = n1*cos_th1-n2*cos_th2
        b = n1*cos_th1+n2*cos_th2
        return a/b
    def rp(cos_th1, cos_th2, n1, n2):
        a = n2*cos_th1-n1*cos_th2
        b = n2*cos_th1+n1*cos_th2
        return a/b    
    if np.sin(th) >= n2/n1:
        res = 1.
    else:
        res = 0.5 * ((rs(cos_th1, cos_th2, n1, n2))**2 + 
                     (rp(cos_th1, cos_th2, n1, n2))**2)
    if res < 1e-6:
        res = 0.
    return res

@jit(nopython=True)
def move(old_p, z_start_table, z_end_table, n_table, mu_a_table, mu_s_table, absorbtion_output):
    p = old_p * 1.
    
    if len(absorbtion_output) == 1:
        buf_m = p[6]
    
    # Cacl random non-dimensional l
    l_rand = -np.log(np.random.random(1))[0]

    while l_rand > 0.:
        layer_index = int(p[-1])
        z_start = z_start_table[layer_index]
        z_end = z_end_table[layer_index]

        mu_a = mu_a_table[layer_index]
        mu_s = mu_s_table[layer_index]
        mu_t = mu_a + mu_s

        l_free_path = 1 / mu_t
        l = l_rand * l_free_path

        new_p_z = (p[2] + l * p[5])
        if z_start < new_p_z < z_end:
            # non layer bound interaction
            new_p_x = (p[0] + l * p[3])
            new_p_y = (p[1] + l * p[4])
            p[0], p[1], p[2] = new_p_x, new_p_y, new_p_z
            p[6] = (p[6] * np.exp(-mu_a * l))
            break
        else:
            # layer boundary interaction

            # Cacl partial moving
            if p[5] > 0:
                l_part = ((z_end - p[2]) / p[5])
            else:
                l_part = ((z_start - p[2]) / p[5])

            # Cacl new random non-dimensional l
            l_rand = l_rand - mu_t * l_part

            # Cacl new coordinate (on boundary)
            new_p_x = (p[0] + l_part * p[3])
            new_p_y = (p[1] + l_part * p[4])
            new_p_z = (p[2] + l_part * p[5])

            p[0], p[1], p[2] = new_p_x, new_p_y, new_p_z
            p[6] = (p[6] * np.exp(-mu_a * l_part))

            # Check reflection (change layer)
            p = reflection(p, n_table)
            if (p[-1] == -1 or p[-1] == -2):
                break
    
    if len(absorbtion_output) == 1:
        absorbtion_output[0] += buf_m - p[6]
    
    return p

# %%
# engin function

def mlmc(parameters, geometry):
    N = parameters['N']
    generator_distribution = parameters['generator_distribution']
    
    layers_number = len(geometry)
    z_start_table = np.array([geometry[i]['z_start']  for i in range(layers_number)])
    z_end_table = np.array([geometry[i]['z_end']  for i in range(layers_number)])
    n_table = np.array([geometry[i]['n']  for i in range(layers_number)])
    mu_a_table = np.array([geometry[i]['mu_a']  for i in range(layers_number)])
    mu_s_table = np.array([geometry[i]['mu_s']  for i in range(layers_number)])
    g_table = np.array([geometry[i]['g']  for i in range(layers_number)])
    
    
    if parameters['absorbtion_saving_mode'] == 'Full':
        absorbtion_output = np.zeros(1)
    elif parameters['absorbtion_saving_mode'] == 'Mapping':
        pass #to do mesh
    
    
    if parameters['radiation_saving_mode'] == 'FIS':
        radiation_output = np.zeros(4)
        cz_collimate = parameters['FIS_collimated_aperture']
        @jit(nopython=True)
        def radiation_saving(p, radiation_output, cz_collimate=cz_collimate):
            cz = p[5]
            m = p[6]

            if cz > cz_collimate:
                radiation_output[0] += m
            elif cz > 0:
                radiation_output[1] += m
            elif cz > -cz_collimate:
                radiation_output[2] += m
            else:
                radiation_output[3] += m
            return radiation_output 
        
    elif parameters['radiation_saving_mode'] == 'MIS':
        radiation_output = np.concatenate(([parameters['MIS_positions_table']], 
                                           np.zeros((2, len(parameters['MIS_positions_table'])))), axis=0)
        sphere_d = 80
        port_d = 12.5
        @jit(nopython=True)
        def radiation_saving(p, radiation_output, sphere_d=sphere_d, port_d=port_d):
            for i in range(len(radiation_output[0])):
                if p[-1] == -2:
                    px = p[0] + radiation_output[0, i] * p[3]
                    py = p[1] + radiation_output[0, i] * p[4]
                    if 4 * (px**2 + py**2) < port_d**2:
                        radiation_output[1, i] += p[6]
                elif p[-1] == -1:
                    px = p[0] + radiation_output[0, i] * p[3]
                    py = p[1] + radiation_output[0, i] * p[4]
                    pxd = p[0] + (radiation_output[0, i] + sphere_d) * p[3]
                    pyd = p[1] + (radiation_output[0, i] + sphere_d) * p[4]
                    if (4 * (px**2 + py**2) < port_d**2) and (4 * (pxd**2 + pyd**2) > port_d**2):
                        radiation_output[2, i] += p[6]
            return radiation_output
        
    elif parameters['radiation_saving_mode'] == 'MIS_Thorlabs':
        radiation_output = np.concatenate(([parameters['MIS_positions_table']], 
                                           np.zeros((2, len(parameters['MIS_positions_table'])))), axis=0)
        sphere_d = 80
        port_d = 12.5
        port_h = 3
        
        @jit(nopython=True)
        def radiation_saving(p, radiation_output, sphere_d=sphere_d, port_d=port_d, port_h=port_h):
            port_d2 =  port_d**2
            for i in range(len(radiation_output[0])):
                if p[-1] == -2:
                    px = p[0] + (radiation_output[0, i]) * p[3]
                    py = p[1] + (radiation_output[0, i]) * p[4] 
                    if 4 * (px**2 + py**2) < port_d2:
                        pxh = p[0] + (radiation_output[0, i] + port_h) * p[3]
                        pyh = p[1] + (radiation_output[0, i] + port_h) * p[4]
                        if 4 * (pxh**2 + pyh**2) < port_d2:
                            px2h = p[0] + (radiation_output[0, i] + 2*port_h) * p[3]
                            py2h = p[1] + (radiation_output[0, i] + 2*port_h) * p[4]
                            if 4 * (px2h**2 + py2h**2) > port_d2:
                                radiation_output[1, i] += 0.5 * p[6]
                            else:
                                radiation_output[1, i] += p[6]
                    
                elif p[-1] == -1:
                    px = p[0] + (radiation_output[0, i]) * p[3]
                    py = p[1] + (radiation_output[0, i]) * p[4] 
                    if 4 * (px**2 + py**2) < port_d2:
                        pxh = p[0] + (radiation_output[0, i] + port_h) * p[3]
                        pyh = p[1] + (radiation_output[0, i] + port_h) * p[4]
                        if 4 * (pxh**2 + pyh**2) < port_d2:
                            px2h = p[0] + (radiation_output[0, i] + 2*port_h) * p[3]
                            py2h = p[1] + (radiation_output[0, i] + 2*port_h) * p[4]
                            if 4 * (px2h**2 + py2h**2) > port_d2:
                                radiation_output[2, i] += 0.5 * p[6]
                            else:
                                px2hd = p[0] + (radiation_output[0, i] + 2*port_h + sphere_d) * p[3]
                                py2hd = p[1] + (radiation_output[0, i] + 2*port_h + sphere_d) * p[4]
                                if 4 * (px2hd**2 + py2hd**2) > port_d2:
                                    radiation_output[2, i] += p[6]
                                else:
                                    px2hdh = p[0] + (radiation_output[0, i] + 3*port_h + sphere_d) * p[3]
                                    py2hdh = p[1] + (radiation_output[0, i] + 3*port_h + sphere_d) * p[4]
                                    if 4 * (px2hdh**2 + py2hdh**2) > port_d2:
                                        radiation_output[2, i] += 0.5 * p[6]
                                        
            return radiation_output
    
    @jit(nopython=True)
    def mlms_run(N, generator_distribution,
                z_start_table, z_end_table, n_table, mu_a_table, mu_s_table, g_table,
                radiation_output, absorbtion_output):
        # p = (x,y,z,cx,cy,cz,m,a)
        for i in range(N):
            #generate photon and calc first reflection part
            p = generator(generator_distribution, n_table[0], radiation_output)

            #tracing photon
            for j in range(10**3):   #while True         
                #calc move and absorbtion
                p = move(p, z_start_table, z_end_table, n_table, mu_a_table, mu_s_table, absorbtion_output)

                #calc outlet and termination
                if (p[-1] == -1 or p[-1] == -2):
                    radiation_saving(p, radiation_output)
                    break
                else:
                    p = term(p)

                #calc scattering act
                p = turn(p, g_table[int(p[-1])])
        return radiation_output, absorbtion_output
    
    radiation_output, absorbtion_output = mlms_run(N, generator_distribution,
                z_start_table, z_end_table, n_table, mu_a_table, mu_s_table, g_table,
                radiation_output, absorbtion_output)
        
    # forming output data
    if parameters['radiation_saving_mode'] == 'FIS':
        radiation_output = 100 * radiation_output / N
        absorbtion_output = 100 * absorbtion_output / N
        check_sum = (np.sum(radiation_output) + absorbtion_output)
    elif parameters['radiation_saving_mode'] == 'MIS' or parameters['radiation_saving_mode'] == 'MIS_Thorlabs':
        radiation_output[1:] = 100 * radiation_output[1:] / N
        absorbtion_output = 100 * absorbtion_output / N
        check_sum = radiation_output[1,0] + radiation_output[2,0] + absorbtion_output[0]
        
    return {'radiation_output':radiation_output, 'absorbtion_output': absorbtion_output, 'check_sum': check_sum}

# %%
# %%time
# size [mm] koef [mm-1]
geometry = [
            {'z_start': 0, 'z_end': 1, 'mu_a': 0, 'mu_s': 1, 'g': 1, 'n': 1.5},
            {'z_start': 1, 'z_end': 2, 'mu_a': 0.1, 'mu_s': 1, 'g': 0.8, 'n': 1.4},
            {'z_start': 2, 'z_end': 3, 'mu_a': 0, 'mu_s': 1, 'g': 1, 'n': 1.5}
           ]

parameters = {'N': 100000, 
              'generator_distribution': 'Gauss', # Gauss // Cyrcle
              'absorbtion_saving_mode': 'Full', # Full // Mapping(to do)
              'radiation_saving_mode': 'MIS_Thorlabs', # FIS // MIS // MIS_Thorlabs // Rings(to do)
              'FIS_collimated_aperture': 0.984,
              'MIS_positions_table': np.linspace(0,200,100)
             }

output_MIS_Thorlabs = mlmc(parameters, geometry)
# Out:
# CPU times: total: 3.27 s
# Wall time: 3.33 s

# %%
# %%time
parameters['radiation_saving_mode'] = 'MIS'
output_MIS = mlmc(parameters, geometry)
# Out:
# CPU times: total: 2.23 s
# Wall time: 2.28 s

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
ax1.plot(output_MIS_Thorlabs['radiation_output'][0],output_MIS_Thorlabs['radiation_output'][1])
ax1.plot(output_MIS['radiation_output'][0],output_MIS['radiation_output'][1])
ax2.plot(output_MIS_Thorlabs['radiation_output'][0],output_MIS_Thorlabs['radiation_output'][2])
ax2.plot(output_MIS['radiation_output'][0],output_MIS['radiation_output'][2])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
ax1.plot(output_MIS_Thorlabs['radiation_output'][0],np.log10(output_MIS_Thorlabs['radiation_output'][1]))
ax1.plot(output_MIS['radiation_output'][0],np.log10(output_MIS['radiation_output'][1]))
ax2.plot(output_MIS_Thorlabs['radiation_output'][0],np.log10(output_MIS_Thorlabs['radiation_output'][2]))
ax2.plot(output_MIS['radiation_output'][0],np.log10(output_MIS['radiation_output'][2]))

# %%
#cProfile.run("mlmc(parameters, geometry)",sort='tottime')
# Out:
#          1146152 function calls (1083627 primitive calls) in 2.911 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    1.269    1.269    1.270    1.270 3125272417.py:111(mlms_run)
#      1870    0.529    0.000    0.568    0.000 ffi.py:149(__call__)
#      2153    0.185    0.000    0.189    0.000 contextlib.py:261(helper)
#      1300    0.091    0.000    0.092    0.000 win32.py:92(_winapi_test)
# 34579/5973    0.043    0.000    0.061    0.000 ir.py:313(_rec_list_vars)
#    228736    0.035    0.000    0.048    0.000 {built-in method builtins.isinstance}
# 26594/12638    0.021    0.000    0.080    0.000 {method 'format' of 'str' objects}
# 15033/6513    0.011    0.000    0.074    0.000 _utils.py:44(__str__)
#      4291    0.011    0.000    0.063    0.000 values.py:544(_to_string)
#      4213    0.010    0.000    0.037    0.000 instructions.py:13(__init__)
# 11442/11430    0.010    0.000    0.019    0.000 _utils.py:54(get_reference)
#      1300    0.009    0.000    0.105    0.000 win32.py:98(winapi_test)
# 28470/28377    0.009    0.000    0.019    0.000 {built-in method builtins.getattr}
#      1300    0.008    0.000    0.130    0.000 ansitowin32.py:73(__init__)
#     12621    0.008    0.000    0.011    0.000 targetconfig.py:111(getter)
#     16854    0.008    0.000    0.008    0.000 {built-in method _abc._abc_instancecheck}
#       234    0.008    0.000    0.134    0.001 functions.py:281(get_call_type)
#        20    0.007    0.000    0.048    0.002 analysis.py:23(compute_use_defs)
#      5272    0.007    0.000    0.013    0.000 _utils.py:24(deduplicate)
#       220    0.007    0.000    0.024    0.000 numpy_support.py:357(ufunc_find_matching_loop)
#      5353    0.006    0.000    0.025    0.000 values.py:557(_set_name)
#      5118    0.006    0.000    0.031    0.000 values.py:537(__init__)
#     16854    0.006    0.000    0.013    0.000 abc.py:117(__instancecheck__)
# 7040/5206    0.006    0.000    0.010    0.000 abstract.py:117(__hash__)
#      4760    0.005    0.000    0.014    0.000 event.py:227(notify)
#       574    0.005    0.000    0.015    0.000 utils.py:311(order_by_target_specificity)
#       650    0.005    0.000    0.148    0.000 errors.py:301(_markup)
# 6961/6886    0.005    0.000    0.007    0.000 abstract.py:120(__eq__)
#      5353    0.005    0.000    0.019    0.000 _utils.py:16(register)
#      1189    0.005    0.000    0.017    0.000 context.py:542(_rate_arguments)
# 10082/9584    0.005    0.000    0.214    0.000 {built-in method builtins.next}
#     19478    0.004    0.000    0.008    0.000 {method 'get' of 'dict' objects}
#      3866    0.004    0.000    0.019    0.000 event.py:193(broadcast)
#      3603    0.004    0.000    0.008    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#       130    0.004    0.000    0.023    0.000 context.py:592(resolve_overload)
#      1414    0.004    0.000    0.007    0.000 os.py:674(__getitem__)
#      1300    0.004    0.000    0.135    0.000 initialise.py:74(wrap_stream)
#      1433    0.004    0.000    0.017    0.000 instructions.py:638(__init__)
#  1155/392    0.004    0.000    0.030    0.000 context.py:182(get_meminfos)
#      1433    0.004    0.000    0.008    0.000 instructions.py:653(descr)
#     25777    0.004    0.000    0.004    0.000 {method 'append' of 'list' objects}
#      4232    0.004    0.000    0.007    0.000 values.py:564(_get_reference)
# 4129/4103    0.004    0.000    0.104    0.000 {built-in method builtins.any}
#      4213    0.004    0.000    0.005    0.000 builder.py:351(_insert)
#     27999    0.004    0.000    0.004    0.000 {method 'extend' of 'list' objects}
#      3050    0.004    0.000    0.010    0.000 numpy_support.py:339(ufunc_can_cast)
#      4960    0.004    0.000    0.007    0.000 utils.py:466(stream_list)
# 9350/9259    0.004    0.000    0.013    0.000 {method 'join' of 'str' objects}
#      2153    0.003    0.000    0.004    0.000 contextlib.py:86(__init__)
# 24237/23517    0.003    0.000    0.004    0.000 {built-in method builtins.len}
#      2262    0.003    0.000    0.010    0.000 weakref.py:415(__getitem__)
#        63    0.003    0.000    0.004    0.000 analysis.py:81(def_reach)
#      1433    0.003    0.000    0.023    0.000 builder.py:966(extract_value)
#      1300    0.003    0.000    0.013    0.000 ansitowin32.py:43(isatty)
#      2949    0.003    0.000    0.003    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#      3866    0.003    0.000    0.007    0.000 event.py:84(__init__)
#      1934    0.003    0.000    0.007    0.000 typeconv.py:40(check_compatible)
#       126    0.003    0.000    0.004    0.000 analysis.py:91(liveness)
#      1933    0.003    0.000    0.014    0.000 event.py:374(start_event)
#      1933    0.003    0.000    0.017    0.000 event.py:388(end_event)
#         6    0.003    0.001    0.013    0.002 postproc.py:178(_patch_var_dels)
#      1664    0.003    0.000    0.075    0.000 templates.py:349(apply)
#      6123    0.003    0.000    0.005    0.000 ir.py:1221(find_insts)
#       436    0.003    0.000    0.303    0.001 lowering.py:432(lower_inst)
# 2747/2248    0.003    0.000    0.006    0.000 {built-in method builtins.sorted}
#       576    0.003    0.000    0.017    0.000 targetconfig.py:199(<dictcomp>)
#     10061    0.003    0.000    0.003    0.000 _utils.py:13(is_used)
#      1909    0.003    0.000    0.006    0.000 values.py:445(__init__)
#      1034    0.003    0.000    0.005    0.000 functions.py:78(add_error)
#      2380    0.003    0.000    0.004    0.000 event.py:254(on_end)
#      8635    0.003    0.000    0.003    0.000 {method 'startswith' of 'str' objects}
#      9946    0.003    0.000    0.004    0.000 {built-in method builtins.hasattr}
# 8324/6436    0.003    0.000    0.004    0.000 {built-in method builtins.hash}
#       673    0.003    0.000    0.005    0.000 numpy_support.py:125(as_dtype)
#      4783    0.002    0.000    0.053    0.000 ir.py:346(list_vars)
#      1300    0.002    0.000    0.009    0.000 _collections_abc.py:767(__contains__)
#      1314    0.002    0.000    0.008    0.000 types.py:77(__call__)
#      2600    0.002    0.000    0.094    0.000 win32.py:99(<genexpr>)
#        18    0.002    0.000    0.006    0.000 analysis.py:118(compute_dead_maps)
# 2153/1904    0.002    0.000    0.007    0.000 contextlib.py:123(__exit__)
#      2380    0.002    0.000    0.012    0.000 context.py:517(can_convert)
#       650    0.002    0.000    0.137    0.000 initialise.py:23(init)
#     12998    0.002    0.000    0.003    0.000 {method 'add' of 'set' objects}
#      2948    0.002    0.000    0.006    0.000 <__array_function__ internals>:2(can_cast)
#       220    0.002    0.000    0.037    0.000 npydecl.py:98(generic)
#      1870    0.002    0.000    0.020    0.000 ffi.py:73(__exit__)
#    182/42    0.002    0.000    0.670    0.016 typeinfer.py:580(resolve)
#      1870    0.002    0.000    0.017    0.000 ffi.py:67(__enter__)
#      3910    0.002    0.000    0.003    0.000 event.py:50(_guard_kind)
#      4960    0.002    0.000    0.011    0.000 templates.py:1307(new_registrations)
#       380    0.002    0.000    0.007    0.000 instructions.py:507(__init__)
#       560    0.002    0.000    0.010    0.000 base.py:360(install_registry)
#      9045    0.002    0.000    0.002    0.000 {method 'values' of 'dict' objects}
#       392    0.002    0.000    0.035    0.000 context.py:199(_call_incref_decref)
#      4960    0.002    0.000    0.003    0.000 utils.py:475(sublist_iterator)
#     12678    0.002    0.000    0.002    0.000 targetconfig.py:38(default)
#      1953    0.002    0.000    0.004    0.000 target_extension.py:14(__getitem__)
#     10306    0.002    0.000    0.002    0.000 abstract.py:95(key)
# 2980/2830    0.002    0.000    0.006    0.000 misc.py:52(unliteral)
#      4760    0.002    0.000    0.002    0.000 event.py:122(is_start)
#      3135    0.002    0.000    0.030    0.000 ir.py:594(list_vars)
#        24    0.002    0.000    0.310    0.013 lowering.py:283(lower_block)
#        70    0.002    0.000    0.013    0.000 cpu.py:69(load_additional_registries)
#       340    0.002    0.000    0.004    0.000 context.py:287(find_matching_getattr_template)
#      1291    0.002    0.000    0.003    0.000 typeinfer.py:911(__getitem__)
#       365    0.002    0.000    0.062    0.000 typeof.py:25(typeof)
#      1955    0.002    0.000    0.002    0.000 registry.py:95(__getitem__)
#       155    0.002    0.000    0.005    0.000 instructions.py:65(__init__)
#      2380    0.002    0.000    0.002    0.000 event.py:249(on_start)
#      1300    0.002    0.000    0.002    0.000 ansitowin32.py:55(closed)
#      4582    0.002    0.000    0.005    0.000 templates.py:361(<genexpr>)
#       345    0.002    0.000    0.013    0.000 cgutils.py:900(gep)
#   229/161    0.002    0.000    0.074    0.000 base.py:540(get_function)
#   770/568    0.002    0.000    0.003    0.000 pprint.py:529(_safe_repr)
#       220    0.002    0.000    0.004    0.000 npydecl.py:26(_handle_inputs)
#      1414    0.002    0.000    0.003    0.000 os.py:746(encodekey)
#       348    0.002    0.000    0.104    0.000 errors.py:508(__init__)
#       182    0.002    0.000    0.003    0.000 typeinfer.py:508(fold_arg_vars)
#      2710    0.002    0.000    0.003    0.000 types.py:30(__ne__)
#      1632    0.002    0.000    0.002    0.000 errors.py:803(new_error_context)
# 1779/1775    0.002    0.000    0.003    0.000 values.py:455(_get_reference)
# 2153/1904    0.002    0.000    0.201    0.000 contextlib.py:114(__enter__)
#       245    0.002    0.000    0.006    0.000 ir.py:575(__repr__)
#      4349    0.002    0.000    0.003    0.000 {built-in method builtins.issubclass}
#       220    0.002    0.000    0.074    0.000 values.py:1131(<listcomp>)
#       148    0.002    0.000    0.015    0.000 cgutils.py:362(alloca_once)
#        18    0.002    0.000    0.002    0.000 analysis.py:190(compute_live_variables)
#        99    0.001    0.000    0.004    0.000 inspect.py:2152(_signature_from_function)
#       155    0.001    0.000    0.005    0.000 instructions.py:120(_descr)
#      1870    0.001    0.000    0.015    0.000 base.py:1257(enter_fn)
#        75    0.001    0.000    0.002    0.000 {built-in method builtins.__build_class__}
#       433    0.001    0.000    0.007    0.000 builder.py:768(store)
#      1870    0.001    0.000    0.018    0.000 base.py:1260(exit_fn)
#       855    0.001    0.000    0.016    0.000 models.py:629(get)
#       529    0.001    0.000    0.008    0.000 builder.py:755(load)
#      1897    0.001    0.000    0.011    0.000 manager.py:22(lookup)
#        48    0.001    0.000    0.006    0.000 analysis.py:235(compute_cfg_from_blocks)
#      3321    0.001    0.000    0.001    0.000 controlflow.py:116(successors)
#       354    0.001    0.000    0.066    0.000 context.py:374(resolve_value_type)
#      4109    0.001    0.000    0.002    0.000 _utils.py:71(_stringify_metadata)
#       4/2    0.001    0.000    0.678    0.339 typeinfer.py:142(propagate)
#       138    0.001    0.000    0.041    0.000 base.py:53(_find)
#      4615    0.001    0.000    0.001    0.000 {method 'insert' of 'list' objects}
# 3021/1221    0.001    0.000    0.001    0.000 packer.py:144(rec)
#      1468    0.001    0.000    0.008    0.000 functions.py:230(_unlit_non_poison)
#       440    0.001    0.000    0.003    0.000 numpy_support.py:387(choose_types)
#       720    0.001    0.000    0.006    0.000 context.py:428(install_registry)
#        38    0.001    0.000    0.093    0.002 lowering.py:690(lower_binop)
#       796    0.001    0.000    0.001    0.000 controlflow.py:366(_add_edge)
#      1730    0.001    0.000    0.002    0.000 ir.py:379(__getattr__)
#       380    0.001    0.000    0.006    0.000 instructions.py:529(descr)
#       268    0.001    0.000    0.003    0.000 interpreter.py:692(store)
#    224/50    0.001    0.000    0.667    0.013 context.py:233(_resolve_user_function_type)
#       540    0.001    0.000    0.004    0.000 errors.py:467(catch_warnings)
#   406/388    0.001    0.000    0.010    0.000 abstract.py:60(__call__)
#       363    0.001    0.000    0.003    0.000 instructions.py:683(descr)
#       650    0.001    0.000    0.138    0.000 errors.py:224(__init__)
#       650    0.001    0.000    0.001    0.000 errors.py:243(__exit__)
#     50/25    0.001    0.000    1.636    0.065 compiler_machinery.py:264(_runPass)
#      1052    0.001    0.000    0.005    0.000 ssa.py:190(_run_ssa_block_pass)
#       601    0.001    0.000    0.013    0.000 models.py:709(getter)
#      5598    0.001    0.000    0.001    0.000 builder.py:195(block)
#       363    0.001    0.000    0.005    0.000 instructions.py:665(__init__)
#      1983    0.001    0.000    0.001    0.000 npytypes.py:458(key)
#      3066    0.001    0.000    0.002    0.000 ir.py:251(__hash__)
#       529    0.001    0.000    0.003    0.000 instructions.py:413(descr)
#    370/54    0.001    0.000    0.001    0.000 packer.py:175(rec)
#      1697    0.001    0.000    0.011    0.000 manager.py:33(__getitem__)
#       574    0.001    0.000    0.002    0.000 target_extension.py:52(get_local_target)
#      3513    0.001    0.000    0.001    0.000 controlflow.py:124(predecessors)
#       224    0.001    0.000    0.001    0.000 typeof.py:60(_typeof_buffer)
#        99    0.001    0.000    0.006    0.000 inspect.py:2246(_signature_from_callable)
#      4890    0.001    0.000    0.001    0.000 {built-in method time.perf_counter}
#      4903    0.001    0.000    0.001    0.000 values.py:554(_get_name)
#       433    0.001    0.000    0.003    0.000 instructions.py:433(descr)
#       414    0.001    0.000    0.002    0.000 inspect.py:2498(__init__)
#      1300    0.001    0.000    0.001    0.000 ansitowin32.py:116(get_win32_calls)
#       108    0.001    0.000    0.243    0.002 lowering.py:1133(lower_expr)
#       499    0.001    0.000    0.005    0.000 values.py:1061(__init__)
#       380    0.001    0.000    0.009    0.000 builder.py:921(gep)
#       170    0.001    0.000    0.004    0.000 lowering.py:379(<listcomp>)
#       416    0.001    0.000    0.002    0.000 templates.py:183(signature)
#       867    0.001    0.000    0.001    0.000 values.py:863(__iter__)
#         2    0.001    0.000    0.004    0.002 ir_utils.py:2297(fixup_var_define_in_scope)
#      1936    0.001    0.000    0.001    0.000 enum.py:431(__getitem__)
#      2536    0.001    0.000    0.002    0.000 abc.py:121(__subclasscheck__)
#       286    0.001    0.000    0.004    0.000 typeinfer.py:1092(add_type)
#       140    0.001    0.000    0.002    0.000 ntpath.py:450(normpath)
#     366/7    0.001    0.000    0.008    0.001 pprint.py:163(_format)
#      2019    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x00007FF88027BC60}
#      1951    0.001    0.000    0.001    0.000 utils.py:337(key)
#      6144    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
#       220    0.001    0.000    0.039    0.000 npydecl.py:202(generic)
#       389    0.001    0.000    0.010    0.000 value.py:143(name)
#        22    0.001    0.000    0.008    0.000 ir.py:1254(dump)
#       156    0.001    0.000    0.006    0.000 module.py:45(add_metadata)
#       454    0.001    0.000    0.002    0.000 context.py:455(_lookup_global)
#      1414    0.001    0.000    0.001    0.000 os.py:740(check_str)
#      3653    0.001    0.000    0.001    0.000 templates.py:50(args)
#       448    0.001    0.000    0.001    0.000 {built-in method _functools.reduce}
#         4    0.001    0.000    0.061    0.015 registry.py:54(apply)
#        69    0.001    0.000    0.057    0.001 cgutils.py:99(__init__)
#       386    0.001    0.000    0.002    0.000 types.py:423(wrap_constant_value)
#      2100    0.001    0.000    0.001    0.000 {method 'encode' of 'str' objects}
#       646    0.001    0.000    0.001    0.000 controlflow.py:381(_dfs)
#       650    0.001    0.000    0.001    0.000 errors.py:237(__init__)
#       499    0.001    0.000    0.001    0.000 values.py:1015(__init__)
#      1031    0.001    0.000    0.002    0.000 lowering.py:341(_disable_sroa_like_opt)
#      3866    0.001    0.000    0.001    0.000 event.py:92(kind)
#      4426    0.001    0.000    0.001    0.000 {method 'rstrip' of 'str' objects}
#       363    0.001    0.000    0.006    0.000 builder.py:976(insert_value)
#       273    0.001    0.000    0.001    0.000 ir.py:1210(find_exprs)
#         2    0.001    0.000    0.006    0.003 interpreter.py:285(peep_hole_delete_with_exit)
#       358    0.001    0.000    0.009    0.000 value.py:206(is_declaration)
#      1311    0.001    0.000    0.001    0.000 types.py:240(format_constant)
#       390    0.001    0.000    0.006    0.000 ir.py:862(__str__)
#      1116    0.001    0.000    0.002    0.000 {built-in method builtins.all}
#       529    0.001    0.000    0.005    0.000 instructions.py:408(__init__)
#       227    0.001    0.000    0.018    0.000 lowering.py:1515(decref)
#       730    0.001    0.000    0.003    0.000 ffi.py:316(close)
#       220    0.001    0.000    0.001    0.000 numpy_support.py:276(supported_ufunc_loop)
#         2    0.001    0.000    0.009    0.004 byteflow.py:78(run)
#       224    0.001    0.000    0.005    0.000 typeof.py:39(typeof_impl)
#       590    0.001    0.000    0.016    0.000 module.py:213(__next__)
#       464    0.001    0.000    0.001    0.000 __init__.py:517(cast)
#        96    0.001    0.000    0.003    0.000 arraydecl.py:20(get_array_index_type)
#       148    0.001    0.000    0.115    0.001 typeinfer.py:699(__call__)
#       219    0.001    0.000    0.001    0.000 api.py:952(_builtin_function_type)
#        26    0.001    0.000    0.001    0.000 controlflow.py:577(_find_back_edges)
#      2536    0.001    0.000    0.001    0.000 {built-in method _abc._abc_subclasscheck}
#      1460    0.001    0.000    0.001    0.000 models.py:673(get_field_position)
#       751    0.001    0.000    0.008    0.000 functions.py:305(<listcomp>)
#      1934    0.001    0.000    0.001    0.000 {built-in method numba.core.typeconv._typeconv.check_compatible}
#      1433    0.001    0.000    0.001    0.000 instructions.py:654(<listcomp>)
#       331    0.001    0.000    0.001    0.000 ntpath.py:124(splitdrive)
#      2380    0.001    0.000    0.001    0.000 event.py:132(is_end)
#       701    0.001    0.000    0.003    0.000 ffi.py:359(__del__)
#       576    0.001    0.000    0.001    0.000 {built-in method builtins.repr}
#        24    0.001    0.000    0.007    0.000 inline_closurecall.py:1350(_inline_const_arraycall)
#       447    0.001    0.000    0.002    0.000 base.py:127(_match)
#       135    0.001    0.000    0.001    0.000 ntpath.py:180(split)
#      1870    0.001    0.000    0.001    0.000 ffi.py:93(__getattr__)
#       225    0.001    0.000    0.002    0.000 analysis.py:66(fix_point_progress)
#       242    0.001    0.000    0.043    0.000 misc.py:61(literal)
#        22    0.001    0.000    0.002    0.000 controlflow.py:660(_find_loops)
#      1844    0.001    0.000    0.001    0.000 __init__.py:1424(debug)
#       982    0.001    0.000    0.001    0.000 values.py:575(function_type)
#       406    0.001    0.000    0.003    0.000 abstract.py:48(_intern)
#       340    0.001    0.000    0.001    0.000 context.py:250(_get_attribute_templates)
#       156    0.001    0.000    0.009    0.000 builder.py:297(if_then)
#       156    0.001    0.000    0.001    0.000 misc.py:90(__init__)
#       252    0.001    0.000    0.004    0.000 byteflow.py:276(dispatch)
#       433    0.001    0.000    0.004    0.000 instructions.py:429(__init__)
#        54    0.001    0.000    0.006    0.000 packer.py:73(__init__)
#       455    0.001    0.000    0.003    0.000 cgutils.py:158(__setattr__)
#       402    0.001    0.000    0.003    0.000 base.py:107(_match_arglist)
#      1300    0.001    0.000    0.001    0.000 ansitowin32.py:22(__init__)
#        18    0.001    0.000    0.082    0.005 postproc.py:70(run)
#        72    0.001    0.000    0.006    0.000 context.py:700(load_additional_registries)
#       173    0.001    0.000    0.037    0.000 lowering.py:1526(_lit_or_omitted)
#       224    0.001    0.000    0.002    0.000 api.py:194(typeof)
#      1951    0.001    0.000    0.003    0.000 target_extension.py:120(inherits_from)
#       244    0.001    0.000    0.003    0.000 builder.py:31(wrapped)
#       200    0.001    0.000    0.002    0.000 instructions.py:323(__init__)
#       214    0.001    0.000    0.019    0.000 lowering.py:1459(delvar)
#       635    0.001    0.000    0.001    0.000 types.py:444(elements)
#      2709    0.001    0.000    0.001    0.000 analysis.py:69(<genexpr>)
#      3411    0.001    0.000    0.001    0.000 {method 'index' of 'tuple' objects}
#    134/84    0.001    0.000    0.065    0.001 functools.py:973(__get__)
#       200    0.001    0.000    0.002    0.000 instructions.py:339(descr)
#       578    0.001    0.000    0.132    0.000 errors.py:316(errmsg)
#      3203    0.001    0.000    0.001    0.000 analysis.py:40(<genexpr>)
#       650    0.001    0.000    0.001    0.000 errors.py:228(__enter__)
#       196    0.001    0.000    0.253    0.001 lowering.py:614(lower_assign)
#       196    0.001    0.000    0.016    0.000 lowering.py:1413(storevar)
#       884    0.001    0.000    0.001    0.000 lowering.py:325(typeof)
#       244    0.001    0.000    0.002    0.000 instructions.py:30(descr)
#      1300    0.001    0.000    0.001    0.000 iostream.py:435(closed)
#       803    0.001    0.000    0.001    0.000 typeinfer.py:121(getone)
#     37/35    0.001    0.000    0.007    0.000 models.py:550(_as)
#      3743    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#       499    0.001    0.000    0.002    0.000 values.py:1048(_to_list)
#       365    0.001    0.000    0.010    0.000 functools.py:883(wrapper)
#       380    0.001    0.000    0.003    0.000 instructions.py:530(<listcomp>)
#       345    0.001    0.000    0.014    0.000 cgutils.py:893(gep_inbounds)
#       296    0.001    0.000    0.002    0.000 builder.py:281(goto_entry_block)
#         2    0.001    0.000    0.010    0.005 lowering.py:349(_find_singly_assigned_variable)
#       650    0.001    0.000    0.001    0.000 initialise.py:67(reinit)
#       538    0.001    0.000    0.001    0.000 values.py:498(__eq__)
#       155    0.001    0.000    0.006    0.000 builder.py:874(call)
#       270    0.001    0.000    0.001    0.000 warnings.py:458(__enter__)
#      2586    0.001    0.000    0.001    0.000 {method 'pop' of 'dict' objects}
#        30    0.001    0.000    0.091    0.003 lowering.py:760(lower_getitem)
#       668    0.001    0.000    0.001    0.000 numpy_support.py:86(from_dtype)
#       593    0.001    0.000    0.001    0.000 value.py:81(__init__)
#    269/49    0.001    0.000    0.001    0.000 packer.py:123(_assign_names)
#       441    0.001    0.000    0.004    0.000 values.py:1080(__str__)
#       248    0.001    0.000    0.015    0.000 targetconfig.py:190(__eq__)
#      1038    0.001    0.000    0.001    0.000 types.py:558(__eq__)
#       365    0.001    0.000    0.001    0.000 functools.py:817(dispatch)
#        54    0.001    0.000    0.005    0.000 context.py:217(_resolve_builtin_function_type)
#        22    0.001    0.000    0.001    0.000 interpreter.py:538(_remove_unused_temporaries)
#       270    0.001    0.000    0.001    0.000 warnings.py:181(_add_filter)
#       234    0.001    0.000    0.001    0.000 functions.py:65(__init__)
#       270    0.001    0.000    0.001    0.000 warnings.py:477(__exit__)
#       248    0.001    0.000    0.001    0.000 byteflow.py:1312(append)
#       193    0.001    0.000    0.003    0.000 builder.py:568(_icmp)
#       436    0.001    0.000    0.005    0.000 inline_closurecall.py:1484(list_var_used)
#       350    0.001    0.000    0.008    0.000 module.py:244(_next)
#       248    0.001    0.000    0.006    0.000 interpreter.py:668(_dispatch)
#         6    0.001    0.000    0.005    0.001 ssa.py:167(_run_block_rewrite)
#       230    0.001    0.000    0.001    0.000 traceback.py:216(clear_frames)
#      3246    0.001    0.000    0.001    0.000 {function _TargetRegistry.__getitem__ at 0x00000225745F34C0}
#       220    0.001    0.000    0.075    0.000 values.py:1129(descr)
#       230    0.001    0.000    0.001    0.000 utils.py:31(erase_traceback)
#        65    0.001    0.000    0.016    0.000 arrayobj.py:91(shape)
#       568    0.001    0.000    0.004    0.000 pprint.py:430(_repr)
#       270    0.001    0.000    0.001    0.000 warnings.py:165(simplefilter)
#       162    0.001    0.000    0.003    0.000 instructions.py:489(__init__)
#       796    0.001    0.000    0.002    0.000 controlflow.py:101(add_edge)
#       297    0.001    0.000    0.001    0.000 ir.py:1481(get_definition)
#        80    0.001    0.000    0.020    0.000 templates.py:698(_get_impl)
#       111    0.001    0.000    0.001    0.000 models.py:715(<listcomp>)
#       715    0.001    0.000    0.001    0.000 types.py:116(__init__)
#       108    0.001    0.000    0.017    0.000 typed_passes.py:604(_get_callable_info)
#      1119    0.001    0.000    0.001    0.000 types.py:231(__eq__)
#         8    0.001    0.000    0.001    0.000 compiler_machinery.py:355(dependency_analysis)
#      1300    0.001    0.000    0.001    0.000 iostream.py:399(isatty)
#       663    0.000    0.000    0.001    0.000 types.py:27(as_pointer)
#       130    0.000    0.000    0.023    0.000 templates.py:272(_select)
#       582    0.000    0.000    0.004    0.000 values.py:507(__hash__)
#       514    0.000    0.000    0.001    0.000 instructions.py:121(descr_arg)
#       469    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:398(parent)
#       224    0.000    0.000    0.002    0.000 cffi_utils.py:39(is_cffi_func)
#       237    0.000    0.000    0.003    0.000 lowering.py:1395(loadvar)
#      1419    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#   687/664    0.000    0.000    0.001    0.000 types.py:127(__eq__)
#       520    0.000    0.000    0.002    0.000 abstract.py:439(literal_type)
#        48    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap>:1002(_find_and_load)
#        70    0.000    0.000    0.003    0.000 scalars.py:78(__init__)
#        99    0.000    0.000    0.001    0.000 inspect.py:2781(__init__)
#      1361    0.000    0.000    0.000    0.000 {built-in method _ctypes.byref}
#        58    0.000    0.000    0.006    0.000 values.py:925(__init__)
#      1933    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         5    0.000    0.000    0.006    0.001 pprint.py:372(_format_dict_items)
#      2948    0.000    0.000    0.000    0.000 multiarray.py:498(can_cast)
#       601    0.000    0.000    0.001    0.000 models.py:684(get_type)
#         4    0.000    0.000    0.001    0.000 executionengine.py:138(_find_module_ptr)
#       484    0.000    0.000    0.044    0.000 base.py:46(find)
#       596    0.000    0.000    0.001    0.000 controlflow.py:94(add_node)
#   434/364    0.000    0.000    0.005    0.000 base.py:703(cast)
#       157    0.000    0.000    0.002    0.000 pprint.py:389(_format_items)
#       410    0.000    0.000    0.007    0.000 lowering.py:1370(_alloca_var)
#      2727    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       440    0.000    0.000    0.001    0.000 numpy_support.py:394(<listcomp>)
#       401    0.000    0.000    0.001    0.000 ir.py:591(<genexpr>)
#       188    0.000    0.000    0.003    0.000 instructions.py:181(descr)
#         5    0.000    0.000    0.025    0.005 codegen.py:652(_optimize_functions)
#       650    0.000    0.000    0.001    0.000 errors.py:232(__exit__)
#        32    0.000    0.000    0.031    0.001 arrayobj.py:329(basic_indexing)
#       182    0.000    0.000    0.002    0.000 typeinfer.py:667(_add_refine_map)
#      2551    0.000    0.000    0.000    0.000 ir.py:271(__contains__)
#      1844    0.000    0.000    0.000    0.000 __init__.py:1689(isEnabledFor)
#       761    0.000    0.000    0.000    0.000 templates.py:269(__init__)
#        40    0.000    0.000    0.002    0.000 ir_utils.py:2191(enforce_no_dels)
#       265    0.000    0.000    0.002    0.000 base.py:493(get_value_type)
#       743    0.000    0.000    0.000    0.000 ffi.py:326(detach)
#       166    0.000    0.000    0.003    0.000 numbers.py:1332(constant_integer)
#      1300    0.000    0.000    0.000    0.000 ansitowin32.py:106(should_wrap)
#         2    0.000    0.000    0.019    0.010 typed_passes.py:520(run_pass)
#       340    0.000    0.000    0.005    0.000 context.py:268(core)
#       240    0.000    0.000    0.006    0.000 module.py:233(_next)
#       220    0.000    0.000    0.001    0.000 builder.py:357(_set_terminator)
#        50    0.000    0.000    0.002    0.000 controlflow.py:394(_eliminate_dead_blocks)
#      2371    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#      1189    0.000    0.000    0.000    0.000 context.py:22(__init__)
#       162    0.000    0.000    0.003    0.000 builder.py:737(alloca)
#       130    0.000    0.000    0.001    0.000 {method 'sort' of 'list' objects}
#       705    0.000    0.000    0.000    0.000 ffi.py:309(__init__)
#       650    0.000    0.000    0.000    0.000 {method 'decode' of 'bytearray' objects}
#       426    0.000    0.000    0.001    0.000 templates.py:38(__init__)
#       867    0.000    0.000    0.001    0.000 values.py:852(__init__)
#       311    0.000    0.000    0.001    0.000 typeinfer.py:54(add_type)
#       109    0.000    0.000    0.001    0.000 typeinfer.py:1647(typeof_expr)
#        85    0.000    0.000    0.002    0.000 typed_passes.py:663(select_template)
#        18    0.000    0.000    0.020    0.001 ir.py:111(strformat)
#       250    0.000    0.000    0.003    0.000 interpreter.py:424(_iter_inst)
#       842    0.000    0.000    0.001    0.000 byteflow.py:1287(get_inst)
#       209    0.000    0.000    0.001    0.000 typeinfer.py:1180(check_var)
#       275    0.000    0.000    0.001    0.000 ir.py:1102(define)
#       433    0.000    0.000    0.001    0.000 enum.py:358(__call__)
#         4    0.000    0.000    0.001    0.000 ir_utils.py:1546(build_definitions)
#   402/365    0.000    0.000    0.027    0.000 ir_utils.py:1525(guard)
#        87    0.000    0.000    0.004    0.000 arrayobj.py:38(set_range_metadata)
#       650    0.000    0.000    0.000    0.000 initialise.py:51(deinit)
#       266    0.000    0.000    0.001    0.000 byteflow.py:1294(make_temp)
#       108    0.000    0.000    0.001    0.000 utils.py:579(unified_function_type)
#      1189    0.000    0.000    0.000    0.000 context.py:27(astuple)
#       170    0.000    0.000    0.006    0.000 context.py:263(resolve_getattr)
#       576    0.000    0.000    0.017    0.000 targetconfig.py:196(values)
#    182/42    0.000    0.000    0.667    0.016 typeinfer.py:1517(resolve_call)
#       637    0.000    0.000    0.001    0.000 ir.py:702(__init__)
#         4    0.000    0.000    0.001    0.000 ir_utils.py:541(remove_dels)
#        15    0.000    0.000    0.002    0.000 templates.py:189(fold_arguments)
#       328    0.000    0.000    0.003    0.000 ssa.py:300(on_assign)
#        50    0.000    0.000    0.004    0.000 instructions.py:191(set_weights)
#       192    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#       651    0.000    0.000    0.000    0.000 ir.py:1261(<genexpr>)
#       195    0.000    0.000    0.018    0.000 typeinfer.py:1451(typeof_assign)
#       900    0.000    0.000    0.000    0.000 debuginfo.py:16(suspend_emission)
#       571    0.000    0.000    0.001    0.000 context.py:52(__getitem__)
#      1863    0.000    0.000    0.000    0.000 postproc.py:190(<genexpr>)
#       568    0.000    0.000    0.003    0.000 pprint.py:439(format)
#       312    0.000    0.000    0.001    0.000 interpreter.py:710(get)
#         4    0.000    0.000    0.002    0.000 analysis.py:291(dead_branch_prune)
#       120    0.000    0.000    0.000    0.000 containers.py:233(__init__)
#       497    0.000    0.000    0.000    0.000 builder.py:241(position_at_end)
#       152    0.000    0.000    0.008    0.000 cgutils.py:166(__getitem__)
#       324    0.000    0.000    0.001    0.000 builder.py:264(goto_block)
#       114    0.000    0.000    0.002    0.000 ffi.py:247(close)
#       220    0.000    0.000    0.001    0.000 numpy_support.py:332(_ufunc_loop_sig)
#       860    0.000    0.000    0.000    0.000 models.py:48(get_argument_type)
#       209    0.000    0.000    0.000    0.000 typeinfer.py:916(__setitem__)
#      1267    0.000    0.000    0.000    0.000 compiler.py:345(__getattr__)
#        58    0.000    0.000    0.006    0.000 values.py:963(descr_prototype)
#      1260    0.000    0.000    0.000    0.000 abstract.py:114(__repr__)
#       255    0.000    0.000    0.001    0.000 bytecode.py:184(next)
#       188    0.000    0.000    0.002    0.000 instructions.py:183(<listcomp>)
#      1080    0.000    0.000    0.000    0.000 ir.py:1264(terminator)
#        93    0.000    0.000    0.006    0.000 base.py:1223(__call__)
#       612    0.000    0.000    0.001    0.000 types.py:121(_to_string)
#       220    0.000    0.000    0.002    0.000 values.py:951(append_basic_block)
#        99    0.000    0.000    0.000    0.000 inspect.py:494(unwrap)
#        85    0.000    0.000    0.000    0.000 templates.py:98(__repr__)
#         2    0.000    0.000    0.001    0.000 ir_utils.py:2011(raise_on_unsupported_feature)
#         4    0.000    0.000    0.013    0.003 codegen.py:1092(<setcomp>)
#       387    0.000    0.000    0.000    0.000 utils.py:373(__setitem__)
#        11    0.000    0.000    0.001    0.000 static_getitem.py:28(apply)
#       156    0.000    0.000    0.001    0.000 module.py:21(_fix_metadata_operands)
#        64    0.000    0.000    0.001    0.000 values.py:792(__init__)
#       635    0.000    0.000    0.000    0.000 types.py:352(__init__)
#        70    0.000    0.000    0.000    0.000 threading.py:82(RLock)
#       149    0.000    0.000    0.004    0.000 cgutils.py:682(unpack_tuple)
#        72    0.000    0.000    0.001    0.000 context.py:415(_load_builtins)
#   185/180    0.000    0.000    0.005    0.000 base.py:514(get_constant_generic)
#       318    0.000    0.000    0.002    0.000 ir.py:579(<genexpr>)
#       220    0.000    0.000    0.002    0.000 instructions.py:177(__init__)
#       499    0.000    0.000    0.004    0.000 values.py:969(<genexpr>)
#        94    0.000    0.000    0.002    0.000 itanium_mangler.py:132(mangle_identifier)
#       414    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#        18    0.000    0.000    0.000    0.000 packer.py:190(unflatten)
#        10    0.000    0.000    0.019    0.002 boxing.py:438(unbox_array)
#        65    0.000    0.000    0.001    0.000 instructions.py:309(descr)
#      1370    0.000    0.000    0.000    0.000 ir.py:1048(__str__)
#       459    0.000    0.000    0.000    0.000 ir.py:1243(append)
#         2    0.000    0.000    0.014    0.007 inline_closurecall.py:82(run)
#       220    0.000    0.000    0.001    0.000 values.py:1111(__init__)
#       255    0.000    0.000    0.001    0.000 bytecode.py:260(<genexpr>)
#       312    0.000    0.000    0.000    0.000 interpreter.py:71(get_assignment_source)
#        67    0.000    0.000    0.003    0.000 cgutils.py:656(pack_array)
#   766/697    0.000    0.000    0.000    0.000 byteflow.py:1486(_flatten_inst_regs)
#      1384    0.000    0.000    0.000    0.000 types.py:246(wrap_constant_value)
#       315    0.000    0.000    0.000    0.000 ir.py:854(__init__)
#      1933    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#       182    0.000    0.000    0.001    0.000 typeinfer.py:515(<listcomp>)
#       152    0.000    0.000    0.009    0.000 cgutils.py:149(__getattr__)
#     34/20    0.000    0.000    0.662    0.033 typeinfer.py:570(__call__)
#       560    0.000    0.000    0.002    0.000 base.py:376(insert_func_defn)
#        94    0.000    0.000    0.002    0.000 builder.py:833(cbranch)
#       738    0.000    0.000    0.000    0.000 functions.py:262(key)
#       270    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#       244    0.000    0.000    0.001    0.000 instructions.py:34(<listcomp>)
#       308    0.000    0.000    0.000    0.000 controlflow.py:600(push_state)
#        93    0.000    0.000    0.007    0.000 base.py:1194(__init__)
#    224/50    0.000    0.000    0.668    0.013 context.py:189(resolve_function_type)
#       560    0.000    0.000    0.001    0.000 base.py:380(_insert_getattr_defn)
#         2    0.000    0.000    0.034    0.017 interpreter.py:336(interpret)
#       648    0.000    0.000    0.000    0.000 numpy_support.py:384(<genexpr>)
#        32    0.000    0.000    0.002    0.000 cgutils.py:736(get_item_pointer2)
#        28    0.000    0.000    0.034    0.001 module.py:11(parse_assembly)
#        93    0.000    0.000    0.107    0.001 base.py:1200(__call__)
#       108    0.000    0.000    0.016    0.000 typed_passes.py:606(get_func_type)
#        90    0.000    0.000    0.003    0.000 arraydecl.py:166(generic)
#       112    0.000    0.000    0.001    0.000 models.py:545(<listcomp>)
#        93    0.000    0.000    0.006    0.000 base.py:1211(_has_loc)
#       560    0.000    0.000    0.001    0.000 base.py:384(_insert_setattr_defn)
#    150/75    0.000    0.000    1.635    0.022 compiler_machinery.py:268(check)
#     23/19    0.000    0.000    0.005    0.000 models.py:557(_from)
#       155    0.000    0.000    0.002    0.000 instructions.py:127(<listcomp>)
#        90    0.000    0.000    0.003    0.000 containers.py:144(from_types)
#        70    0.000    0.000    0.001    0.000 context.py:135(__init__)
#       2/1    0.000    0.000    1.638    1.638 compiler_machinery.py:327(run)
#       254    0.000    0.000    0.025    0.000 context.py:223(decref)
#       221    0.000    0.000    0.019    0.000 typeinfer.py:1384(constrain_statement)
#        70    0.000    0.000    0.021    0.000 base.py:269(refresh)
#       233    0.000    0.000    0.000    0.000 values.py:858(add)
#       220    0.000    0.000    0.003    0.000 numpy_support.py:374(<listcomp>)
#       460    0.000    0.000    0.000    0.000 {method 'clear' of 'frame' objects}
#        17    0.000    0.000    0.020    0.001 callconv.py:547(call_function)
#       138    0.000    0.000    0.004    0.000 base.py:60(_select_compatible)
#       220    0.000    0.000    0.001    0.000 npydecl.py:100(<listcomp>)
#        58    0.000    0.000    0.004    0.000 values.py:932(<listcomp>)
#       291    0.000    0.000    0.003    0.000 values.py:452(_to_string)
#        37    0.000    0.000    0.001    0.000 ir_utils.py:1571(find_callname)
#       560    0.000    0.000    0.002    0.000 base.py:388(_insert_cast_defn)
#        42    0.000    0.000    0.020    0.000 typeinfer.py:467(__call__)
#       571    0.000    0.000    0.000    0.000 context.py:59(__len__)
#       220    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#       520    0.000    0.000    0.000    0.000 typeinfer.py:520(<genexpr>)
#        32    0.000    0.000    0.015    0.000 cgutils.py:694(get_item_pointer)
#       253    0.000    0.000    0.000    0.000 bytecode.py:106(__repr__)
#       253    0.000    0.000    0.000    0.000 bytecode.py:130(_unpack_opargs)
#      1112    0.000    0.000    0.000    0.000 bytecode.py:247(__getitem__)
#        47    0.000    0.000    0.051    0.001 arrayobj.py:71(_make_refs)
#       560    0.000    0.000    0.002    0.000 base.py:392(_insert_get_constant_defn)
#      1286    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        28    0.000    0.000    0.002    0.000 ntpath.py:678(relpath)
#       258    0.000    0.000    0.010    0.000 cgutils.py:142(_get_ptr_by_index)
#        80    0.000    0.000    0.020    0.000 templates.py:607(generic)
#        24    0.000    0.000    0.001    0.000 lowering.py:387(pre_block)
#       224    0.000    0.000    0.000    0.000 cffi_utils.py:29(is_ffi_instance)
#       284    0.000    0.000    0.000    0.000 ir.py:1036(__init__)
#       230    0.000    0.000    0.001    0.000 values.py:1071(add_attribute)
#       660    0.000    0.000    0.001    0.000 npydecl.py:220(<genexpr>)
#       230    0.000    0.000    0.001    0.000 context.py:408(_get_global_type)
#       635    0.000    0.000    0.000    0.000 types.py:359(__getitem__)
#       745    0.000    0.000    0.000    0.000 models.py:532(get_value_type)
#       252    0.000    0.000    0.001    0.000 context.py:228(<listcomp>)
#       440    0.000    0.000    0.000    0.000 numpy_support.py:397(<listcomp>)
#       135    0.000    0.000    0.002    0.000 ir.py:196(short)
#        96    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:166(_get_module_lock)
#       114    0.000    0.000    0.000    0.000 lowering.py:715(try_static_impl)
#       513    0.000    0.000    0.000    0.000 inspect.py:2830(<genexpr>)
#       402    0.000    0.000    0.000    0.000 builder.py:204(function)
#     75/58    0.000    0.000    0.032    0.001 consts.py:24(infer_constant)
#       229    0.000    0.000    0.002    0.000 ssa.py:40(get)
#       199    0.000    0.000    0.000    0.000 builder.py:211(module)
#        19    0.000    0.000    0.007    0.000 types.py:33(_get_ll_pointer_type)
#       234    0.000    0.000    0.000    0.000 utils.py:339(<listcomp>)
#        93    0.000    0.000    0.106    0.001 base.py:1229(wrapper)
#       220    0.000    0.000    0.001    0.000 values.py:1145(_format_name)
#        35    0.000    0.000    0.032    0.001 static_getitem.py:13(match)
#       489    0.000    0.000    0.000    0.000 lowering.py:328(debug_print)
#        24    0.000    0.000    0.001    0.000 array_exprs.py:33(match)
#        26    0.000    0.000    0.083    0.003 module.py:212(<listcomp>)
#       976    0.000    0.000    0.000    0.000 pprint.py:92(__lt__)
#       476    0.000    0.000    0.002    0.000 ir_utils.py:2196(<listcomp>)
#       242    0.000    0.000    0.001    0.000 ir.py:1131(get_or_define)
#         2    0.000    0.000    0.001    0.000 analysis.py:580(rewrite_semantic_constants)
#       220    0.000    0.000    0.002    0.000 numpy_support.py:327(numpy_outputs)
#        22    0.000    0.000    0.047    0.002 arrayobj.py:428(getitem_arraynd_intp)
#         2    0.000    0.000    0.000    0.000 {built-in method nt.stat}
#       154    0.000    0.000    0.005    0.000 cgutils.py:417(get_or_insert_function)
#       220    0.000    0.000    0.000    0.000 npydecl.py:191(ufunc)
#        27    0.000    0.000    0.000    0.000 transforms.py:293(has_multiple_backedges)
#         2    0.000    0.000    0.001    0.000 untyped_passes.py:288(run_pass)
#       125    0.000    0.000    0.000    0.000 utils.py:215(__init__)
#       537    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       504    0.000    0.000    0.000    0.000 analysis.py:138(<genexpr>)
#       911    0.000    0.000    0.000    0.000 containers.py:243(key)
#        36    0.000    0.000    0.010    0.000 analysis.py:71(fix_point)
#       116    0.000    0.000    0.000    0.000 re.py:289(_compile)
#         2    0.000    0.000    0.007    0.004 codegen.py:774(_verify_declare_only_symbols)
#       398    0.000    0.000    0.000    0.000 common.py:9(_decode_string)
#      1124    0.000    0.000    0.000    0.000 models.py:132(has_nrt_meminfo)
#       376    0.000    0.000    0.001    0.000 abstract.py:123(__ne__)
#       235    0.000    0.000    0.000    0.000 byteflow.py:1376(get_top_block)
#        64    0.000    0.000    0.001    0.000 values.py:804(descr)
#       149    0.000    0.000    0.004    0.000 cgutils.py:689(<listcomp>)
#        84    0.000    0.000    0.000    0.000 {built-in method nt._getfullpathname}
#       428    0.000    0.000    0.000    0.000 types.py:205(__new__)
#       162    0.000    0.000    0.001    0.000 instructions.py:495(descr)
#       469    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#       234    0.000    0.000    0.000    0.000 templates.py:281(get_impl_key)
#       912    0.000    0.000    0.000    0.000 models.py:89(traverse)
#       132    0.000    0.000    0.000    0.000 models.py:496(traverse)
#       520    0.000    0.000    0.000    0.000 typeinfer.py:523(<genexpr>)
#      1072    0.000    0.000    0.000    0.000 models.py:233(get_value_type)
#        47    0.000    0.000    0.002    0.000 arrayobj.py:57(make_array)
#       229    0.000    0.000    0.000    0.000 templates.py:128(as_function)
#         2    0.000    0.000    1.235    0.617 typed_passes.py:363(run_pass)
#     50/25    0.000    0.000    1.637    0.065 compiler_lock.py:32(_acquire_compile_lock)
#        92    0.000    0.000    0.000    0.000 ir.py:960(__repr__)
#       122    0.000    0.000    0.001    0.000 values.py:781(__init__)
#       220    0.000    0.000    0.001    0.000 npydecl.py:76(<listcomp>)
#       587    0.000    0.000    0.000    0.000 typeinfer.py:114(defined)
#         2    0.000    0.000    0.005    0.003 codegen.py:768(_finalize_dynamic_globals)
#       130    0.000    0.000    0.024    0.000 templates.py:481(apply)
#         5    0.000    0.000    0.000    0.000 __init__.py:48(create_string_buffer)
#       122    0.000    0.000    0.000    0.000 module.py:138(add_global)
#        80    0.000    0.000    0.003    0.000 targetconfig.py:187(__hash__)
#        15    0.000    0.000    0.000    0.000 inspect.py:2909(_bind)
#        94    0.000    0.000    0.002    0.000 builder.py:825(branch)
#     56/46    0.000    0.000    0.028    0.001 consts.py:56(_do_infer)
#       220    0.000    0.000    0.001    0.000 npydecl.py:52(<listcomp>)
#       235    0.000    0.000    0.000    0.000 byteflow.py:241(_is_implicit_new_block)
#       135    0.000    0.000    0.002    0.000 ir.py:1045(__repr__)
#        31    0.000    0.000    0.000    0.000 models.py:103(traverse_types)
#        17    0.000    0.000    0.014    0.001 typeinfer.py:1557(typeof_global)
#       188    0.000    0.000    0.002    0.000 builder.py:248(append_basic_block)
#       240    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#       214    0.000    0.000    0.000    0.000 ir.py:708(__str__)
#       272    0.000    0.000    0.000    0.000 ir.py:190(with_lineno)
#       220    0.000    0.000    0.000    0.000 ufunc_db.py:32(get_ufunc_info)
#         2    0.000    0.000    0.001    0.000 typed_passes.py:811(_strip_phi_nodes)
#        17    0.000    0.000    0.021    0.001 lowering.py:864(lower_call)
#       151    0.000    0.000    0.002    0.000 models.py:650(set)
#       111    0.000    0.000    0.002    0.000 models.py:708(traverse)
#       220    0.000    0.000    0.001    0.000 npydecl.py:54(<listcomp>)
#       751    0.000    0.000    0.000    0.000 functions.py:306(<dictcomp>)
#       261    0.000    0.000    0.000    0.000 types.py:518(gep)
#         2    0.000    0.000    0.236    0.118 callwrapper.py:127(build_wrapper)
#        28    0.000    0.000    0.000    0.000 values.py:47(<listcomp>)
#    128/28    0.000    0.000    0.002    0.000 itanium_mangler.py:164(mangle_type_or_value)
#        18    0.000    0.000    0.002    0.000 typeinfer.py:239(__call__)
#      1189    0.000    0.000    0.000    0.000 context.py:617(<lambda>)
#       743    0.000    0.000    0.000    0.000 templates.py:46(return_type)
#        17    0.000    0.000    0.020    0.001 lowering.py:1105(_lower_call_normal)
#       380    0.000    0.000    0.000    0.000 types.py:137(gep)
#       157    0.000    0.000    0.002    0.000 pprint.py:219(_pprint_list)
#        17    0.000    0.000    0.002    0.000 callconv.py:454(_get_return_status)
#   140/107    0.000    0.000    0.000    0.000 ir.py:234(__eq__)
#        16    0.000    0.000    0.005    0.000 callconv.py:490(decorate_function)
#       328    0.000    0.000    0.000    0.000 ssa.py:262(on_assign)
#       197    0.000    0.000    0.000    0.000 pprint.py:99(_safe_tuple)
#       209    0.000    0.000    0.000    0.000 typeinfer.py:44(__init__)
#       363    0.000    0.000    0.000    0.000 instructions.py:684(<listcomp>)
#       200    0.000    0.000    0.000    0.000 compiler_machinery.py:414(is_registered)
#       155    0.000    0.000    0.005    0.000 instructions.py:151(descr)
#       150    0.000    0.000    0.000    0.000 compiler_machinery.py:24(__exit__)
#       234    0.000    0.000    0.000    0.000 analysis.py:182(<genexpr>)
#        28    0.000    0.000    0.001    0.000 typeinfer.py:217(__call__)
#       108    0.000    0.000    0.018    0.000 typed_passes.py:661(_do_work_expr)
#       130    0.000    0.000    0.000    0.000 ir.py:372(__init__)
#       380    0.000    0.000    0.000    0.000 misc.py:97(key)
#       302    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#      11/1    0.000    0.000    1.641    1.641 dispatcher.py:915(compile)
# ...
#         2    0.000    0.000    0.000    0.000 cpu_options.py:58(encode)
#         1    0.000    0.000    0.000    0.000 pythonapi.py:866(gil_release)
#         2    0.000    0.000    0.000    0.000 core.py:89(struct)
#         5    0.000    0.000    0.000    0.000 funcdesc.py:109(llvm_func_name)
#         2    0.000    0.000    0.000    0.000 typed_passes.py:120(legalize_return_type)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:775(keys)
#         2    0.000    0.000    0.000    0.000 ir.py:606(__init__)
#        10    0.000    0.000    0.000    0.000 cgutils.py:202(_getpointer)
#         2    0.000    0.000    0.000    0.000 base.py:811(<listcomp>)
#         1    0.000    0.000    0.000    0.000 builtins.py:292(int_impl)
#         2    0.000    0.000    0.000    0.000 arrayobj.py:134(store_item)
#         2    0.000    0.000    0.000    0.000 utils.py:162(shutting_down)
#         1    0.000    0.000    0.000    0.000 pythonapi.py:478(number_long)
#         2    0.000    0.000    0.000    0.000 controlflow.py:209(_topo_order)
#         1    0.000    0.000    0.000    0.000 interpreter.py:633(get_closure_value)
#         5    0.000    0.000    0.000    0.000 byteflow.py:251(_guard_with_as)
#         2    0.000    0.000    0.000    0.000 codegen.py:894(_object_getbuffer_hook)
#         4    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         2    0.000    0.000    0.000    0.000 weakref.py:348(__new__)
#         6    0.000    0.000    0.000    0.000 types.py:291(__new__)
#        14    0.000    0.000    0.000    0.000 base.py:817(get_dummy_type)
#        26    0.000    0.000    0.000    0.000 ssa.py:224(on_other)
#         3    0.000    0.000    0.000    0.000 arraydecl.py:109(keeps_contiguity)
#         1    0.000    0.000    0.000    0.000 pythonapi.py:1138(string_from_string)
#         4    0.000    0.000    0.000    0.000 codegen.py:1083(is_symbol_defined)
#         2    0.000    0.000    0.000    0.000 inline_closurecall.py:126(<listcomp>)
#         2    0.000    0.000    0.001    0.000 config.py:499(reload_config)
#         1    0.000    0.000    0.000    0.000 ir.py:533(phi)
#         2    0.000    0.000    0.000    0.000 targetconfig.py:248(<listcomp>)
#         2    0.000    0.000    0.000    0.000 cpu_options.py:112(_get_values)
#         3    0.000    0.000    0.000    0.000 imputils.py:280(yield_)
#         2    0.000    0.000    0.000    0.000 lowering.py:152(post_lower)
#         2    0.000    0.000    0.000    0.000 compiler_machinery.py:32(__init__)
#         2    0.000    0.000    0.000    0.000 nrt.py:66(library)
#         1    0.000    0.000    0.000    0.000 numbers.py:1272(float_to_integer)
#         3    0.000    0.000    0.000    0.000 npytypes.py:493(box_type)
#         2    0.000    0.000    0.000    0.000 context.py:94(match)
#         1    0.000    0.000    0.000    0.000 cpu_options.py:25(__init__)
#         2    0.000    0.000    0.000    0.000 pythonapi.py:201(get_env_manager)
#         1    0.000    0.000    0.000    0.000 pythonapi.py:331(err_write_unraisable)
#         4    0.000    0.000    0.000    0.000 analysis.py:375(Unknown)
#         2    0.000    0.000    0.000    0.000 controlflow.py:221(_in_loops)
#         2    0.000    0.000    0.000    0.000 callconv.py:105(init_call_helper)
#         2    0.000    0.000    0.000    0.000 compiler_lock.py:52(require_global_compiler_lock)
#         6    0.000    0.000    0.000    0.000 misc.py:101(value)
#         4    0.000    0.000    0.000    0.000 registry.py:38(target_context)
#         2    0.000    0.000    0.000    0.000 dispatcher.py:927(cb_llvm)
#         2    0.000    0.000    0.000    0.000 {built-in method binascii.b2a_base64}
#         4    0.000    0.000    0.000    0.000 values.py:489(<listcomp>)
#         2    0.000    0.000    0.000    0.000 cgutils.py:450(is_null)
#         1    0.000    0.000    0.000    0.000 pythonapi.py:488(long_as_longlong)
#         2    0.000    0.000    0.001    0.000 controlflow.py:225(_post_doms)
#         2    0.000    0.000    0.000    0.000 controlflow.py:229(_idom)
#         5    0.000    0.000    0.000    0.000 dispatcher.py:231(__bool__)
#        13    0.000    0.000    0.000    0.000 event.py:270(duration)
#        13    0.000    0.000    0.000    0.000 contextlib.py:486(__enter__)
#         2    0.000    0.000    0.000    0.000 weakref.py:353(__init__)
#         2    0.000    0.000    0.000    0.000 context.py:639(unify_types)
#        16    0.000    0.000    0.000    0.000 models.py:168(get_argument_type)
#         2    0.000    0.000    0.000    0.000 lowering.py:817(default_handler)
#         2    0.000    0.000    0.000    0.000 funcdesc.py:78(lookup_globals)
#         2    0.000    0.000    0.000    0.000 controlflow.py:233(_df)
#         2    0.000    0.000    0.000    0.000 controlflow.py:373(_remove_node_edges)
#         3    0.000    0.000    0.000    0.000 byteflow.py:1317(get_tos)
#         7    0.000    0.000    0.000    0.000 numbers.py:1186(bool_as_bool)
#         9    0.000    0.000    0.000    0.000 models.py:251(from_return)
#         2    0.000    0.000    0.000    0.000 funcdesc.py:16(qualifying_prefix)
#         2    0.000    0.000    0.000    0.000 controlflow.py:724(__ne__)
#        10    0.000    0.000    0.000    0.000 transforms.py:312(replace)
#         2    0.000    0.000    0.000    0.000 dispatcher.py:758(_callback_add_llvm_timer)
#         3    0.000    0.000    0.000    0.000 ssa.py:297(__init__)
#         2    0.000    0.000    0.000    0.000 utils.py:233(pop)
#         2    0.000    0.000    0.000    0.000 ir.py:1281(insert_after)
#         2    0.000    0.000    0.000    0.000 controlflow.py:197(_exit_points)
#         2    0.000    0.000    0.000    0.000 transforms.py:737(_eliminate_nested_withs)
#         2    0.000    0.000    0.000    0.000 dispatcher.py:295(_make_finalizer)
#         2    0.000    0.000    0.000    0.000 byteflow.py:859(op_DUP_TOP_TWO)
#         2    0.000    0.000    0.000    0.000 context.py:11(__init__)
#         4    0.000    0.000    0.000    0.000 types.py:493(__len__)
#         2    0.000    0.000    0.000    0.000 cpu_options.py:53(__bool__)
#         6    0.000    0.000    0.000    0.000 models.py:450(get_data_type)
#         7    0.000    0.000    0.000    0.000 controlflow.py:168(immediate_dominators)
#         2    0.000    0.000    0.000    0.000 inspect.py:183(isgeneratorfunction)
#         2    0.000    0.000    0.000    0.000 context.py:494(insert_global)
#         2    0.000    0.000    0.000    0.000 pythonapi.py:1172(borrow_none)
#         1    0.000    0.000    0.000    0.000 pythonapi.py:1384(c_api_error)
#         2    0.000    0.000    0.000    0.000 byteflow.py:287(op_NOP)
#         4    0.000    0.000    0.000    0.000 {method 'center' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 imputils.py:260(__init__)
#         2    0.000    0.000    0.000    0.000 byteflow.py:844(<listcomp>)
#         2    0.000    0.000    0.000    0.000 event.py:420(on_exit)
#         5    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 weakref.py:428(__setitem__)
#         2    0.000    0.000    0.000    0.000 cpu_options.py:180(encode)
#         1    0.000    0.000    0.000    0.000 models.py:335(__init__)
#         5    0.000    0.000    0.000    0.000 models.py:717(inner_models)
#         2    0.000    0.000    0.000    0.000 byteflow.py:840(<listcomp>)
#         4    0.000    0.000    0.000    0.000 compiler_machinery.py:99(get_analysis)
#         3    0.000    0.000    0.000    0.000 typeof.py:114(_typeof_float)
#         6    0.000    0.000    0.000    0.000 environment.py:39(__del__)
#         1    0.000    0.000    0.000    0.000 interpreter.py:1663(op_POP_JUMP_IF_TRUE)
#         5    0.000    0.000    0.000    0.000 passes.py:17(_inlining_threshold)
#         2    0.000    0.000    0.000    0.000 inspect.py:81(ismethod)
#         6    0.000    0.000    0.000    0.000 abstract.py:103(mangling_args)
#         1    0.000    0.000    0.000    0.000 dispatcher.py:281(_compilation_chain_init_hook)
#         5    0.000    0.000    0.000    0.000 dispatcher.py:381(is_compiling)
#         1    0.000    0.000    0.000    0.000 byteflow.py:332(op_LOAD_DEREF)
#         2    0.000    0.000    0.000    0.000 codegen.py:621(enable_object_caching)
#         4    0.000    0.000    0.000    0.000 inline_closurecall.py:343(<listcomp>)
#         1    0.000    0.000    0.000    0.000 3125272417.py:8(<listcomp>)
#         2    0.000    0.000    0.000    0.000 inspect.py:64(ismodule)
#         3    0.000    0.000    0.000    0.000 module.py:219(<genexpr>)
#         2    0.000    0.000    0.000    0.000 typeof.py:147(_typeof_str)
#         1    0.000    0.000    0.000    0.000 models.py:229(__init__)
#         3    0.000    0.000    0.000    0.000 controlflow.py:702(<lambda>)
#         2    0.000    0.000    0.000    0.000 interpreter.py:1522(op_INPLACE_ADD)
#         3    0.000    0.000    0.000    0.000 typeinfer.py:438(__init__)
#         4    0.000    0.000    0.000    0.000 inline_closurecall.py:312(check)
#         6    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         5    0.000    0.000    0.000    0.000 imputils.py:425(impl_ret_new_ref)
#         4    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method sys.audit}
#         2    0.000    0.000    0.000    0.000 config.py:123(validate)
#         2    0.000    0.000    0.000    0.000 module.py:110(get_named_metadata)
#         2    0.000    0.000    0.000    0.000 dispatcher.py:754(_callback_add_compiler_timer)
#         3    0.000    0.000    0.000    0.000 typeinfer.py:420(__init__)
#         2    0.000    0.000    0.000    0.000 typeinfer.py:770(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method numba.core.typeconv._typeconv.get_pointer}
#         4    0.000    0.000    0.000    0.000 __init__.py:649(update)
#         2    0.000    0.000    0.000    0.000 utils.py:228(push)
#         2    0.000    0.000    0.000    0.000 bytecode.py:18(get_function_object)
#         3    0.000    0.000    0.000    0.000 byteflow.py:1320(peek)
#         4    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 compiler.py:319(__init__)
#         2    0.000    0.000    0.000    0.000 base.py:41(__init__)
#         2    0.000    0.000    0.000    0.000 parfor.py:701(has_setup)
#         2    0.000    0.000    0.000    0.000 typeinfer.py:136(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#         2    0.000    0.000    0.000    0.000 {method 'from_address' of '_ctypes.PyCArrayType' objects}
#         1    0.000    0.000    0.000    0.000 types.py:281(_format_double)
#         3    0.000    0.000    0.000    0.000 models.py:502(inner_models)
#         4    0.000    0.000    0.000    0.000 analysis.py:487(<listcomp>)
#         4    0.000    0.000    0.000    0.000 controlflow.py:284(dead_nodes)
#         2    0.000    0.000    0.000    0.000 dispatcher.py:220(__init__)
#         2    0.000    0.000    0.000    0.000 byteflow.py:324(op_POP_TOP)
#         2    0.000    0.000    0.000    0.000 codegen.py:1046(<listcomp>)
#         2    0.000    0.000    0.000    0.000 functools.py:420(_unwrap_partial)
#         2    0.000    0.000    0.000    0.000 utils.py:365(__len__)
#         2    0.000    0.000    0.000    0.000 context.py:642(keyfunc)
#         2    0.000    0.000    0.000    0.000 typeinfer.py:908(set_context)
#         2    0.000    0.000    0.000    0.000 typeinfer.py:1234(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 codegen.py:554(name)
#         2    0.000    0.000    0.000    0.000 ssa.py:37(__init__)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:805(__len__)
#         2    0.000    0.000    0.000    0.000 values.py:653(add)
#         2    0.000    0.000    0.000    0.000 callconv.py:591(__init__)
#         1    0.000    0.000    0.000    0.000 3125272417.py:10(<listcomp>)
#         2    0.000    0.000    0.000    0.000 context.py:474(on_disposal)
#         1    0.000    0.000    0.000    0.000 models.py:34(__init__)
#         2    0.000    0.000    0.000    0.000 transforms.py:754(consolidate_multi_exit_withs)
#         2    0.000    0.000    0.000    0.000 codegen.py:543(recorded_timings)
#         3    0.000    0.000    0.000    0.000 inline_closurecall.py:129(<lambda>)
#         1    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.not_}
#         1    0.000    0.000    0.000    0.000 3125272417.py:11(<listcomp>)
#         1    0.000    0.000    0.000    0.000 types.py:343(format_constant)
#         1    0.000    0.000    0.000    0.000 values.py:649(__init__)
#         2    0.000    0.000    0.000    0.000 byteflow.py:1461(__init__)
#         2    0.000    0.000    0.000    0.000 nrt.py:53(_init_guard)
#         4    0.000    0.000    0.000    0.000 ir_utils.py:453(<listcomp>)
#         2    0.000    0.000    0.000    0.000 dispatcher.py:76(__init__)
#         4    0.000    0.000    0.000    0.000 typeinfer.py:1752(propagate_finished)
#         2    0.000    0.000    0.000    0.000 options.py:15(<lambda>)
#         1    0.000    0.000    0.000    0.000 3125272417.py:13(<listcomp>)
#         1    0.000    0.000    0.000    0.000 3125272417.py:9(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {method 'join' of 'bytes' objects}
#         4    0.000    0.000    0.000    0.000 models.py:171(as_argument)
#         1    0.000    0.000    0.000    0.000 funcdesc.py:127(llvm_cfunc_wrapper_name)
#         2    0.000    0.000    0.000    0.000 dispatcher.py:166(_get_implementation)
#         4    0.000    0.000    0.000    0.000 typeinfer.py:1749(propagate_started)
#         2    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 3125272417.py:12(<listcomp>)
#         2    0.000    0.000    0.000    0.000 debuginfo.py:63(__init__)
#         2    0.000    0.000    0.000    0.000 lowering.py:75(init)
#         2    0.000    0.000    0.000    0.000 transforms.py:594(<listcomp>)
#         2    0.000    0.000    0.000    0.000 dispatcher.py:169(_customize_flags)
#         1    0.000    0.000    0.000    0.000 interpreter.py:664(code_freevars)
#         2    0.000    0.000    0.000    0.000 callconv.py:343(_make_call_helper)
#         2    0.000    0.000    0.000    0.000 codegen.py:547(codegen)
#         2    0.000    0.000    0.000    0.000 inline_closurecall.py:785(_debug_dump)
#         2    0.000    0.000    0.000    0.000 models.py:174(from_argument)
#         2    0.000    0.000    0.000    0.000 bytecode.py:178(__iter__)
#         2    0.000    0.000    0.000    0.000 compiler_machinery.py:252(finalized)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.globals}
#         2    0.000    0.000    0.000    0.000 debuginfo.py:73(mark_subprogram)
#         2    0.000    0.000    0.000    0.000 debuginfo.py:79(finalize)
#         2    0.000    0.000    0.000    0.000 interpreter.py:739(op_NOP)
#         2    0.000    0.000    0.000    0.000 base.py:78(<lambda>)
#         2    0.000    0.000    0.000    0.000 typeinfer.py:794(get_call_signature)
#         2    0.000    0.000    0.000    0.000 typeinfer.py:1755(unify_finished)
#         2    0.000    0.000    0.000    0.000 caching.py:95(load_overload)
#         2    0.000    0.000    0.000    0.000 caching.py:98(save_overload)
#         2    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 __init__.py:595(__missing__)
#         1    0.000    0.000    0.000    0.000 ir.py:1014(infer_constant)
#         2    0.000    0.000    0.000    0.000 transforms.py:621(<listcomp>)
#         1    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
