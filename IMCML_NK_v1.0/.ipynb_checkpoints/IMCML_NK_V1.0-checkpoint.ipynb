# %%
import numpy as np 
from scipy.optimize import minimize
from scipy.optimize import curve_fit

from numba import jit

import matplotlib.pyplot as plt
# %matplotlib notebook

import cProfile

from MCML import mlmc

# %%
# %%time
e_Td = (np.loadtxt('Trans.dat') * np.array([1,100])).transpose()
e_Rd = (np.loadtxt('Refl.dat') * np.array([1,100]) - np.array([0,0.7])).transpose()

thickness = np.array([1.04, 0.2, 0.18])

geometry = [
            {'z_start': 0, 'z_end': thickness[0], 
             'mu_a': 0, 'mu_s': 1, 'g': 1, 'n': 1.5},
            {'z_start': thickness[0], 'z_end': thickness[0] + thickness[1], 
             'mu_a': 1.568, 'mu_s': 12.72, 'g': 0.9376, 'n': 1.4},
            {'z_start': thickness[0] + thickness[1], 'z_end': thickness[0] + thickness[1] + thickness[2], 
             'mu_a': 0, 'mu_s': 1, 'g': 1, 'n': 1.5}
           ]

parameters = {'N': 10000, 
              'generator_distribution': 'Gauss', # Gauss // Cyrcle
              'absorbtion_saving_mode': 'Full', # Full // Mapping(to do)
              'radiation_saving_mode': 'MIS_Thorlabs', # FIS // MIS // MIS_Thorlabs // Rings(to do)
              'FIS_collimated_aperture': 0.984,
              'MIS_positions_table': e_Td[0]
             }

output_MIS = mlmc(parameters, geometry)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
ax1.plot(e_Td[0],e_Td[1])
ax2.plot(e_Rd[0],e_Rd[1])
ax1.plot(output_MIS['radiation_output'][0],output_MIS['radiation_output'][1])
ax2.plot(output_MIS['radiation_output'][0],output_MIS['radiation_output'][2])
# Out:
# CPU times: total: 1.83 s
# Wall time: 1.91 s

# %%
# mu_t fitting 3 layers sample (glass - tissue - glass)

def model_mu_t(z, mu_t, amplitude, z_att):
    n_table = np.array([geometry[i]['n']  for i in range(len(geometry))])
    
    def tr(n1, n2):
        return 1 - ((n2-n1) / (n2+n1))**2
    transmition = tr(n_table[0], 1) * tr(n_table[1], n_table[0]) * tr(n_table[2], n_table[1]) * tr(1, n_table[2])  

    return 100 * (np.exp(- mu_t * (geometry[1]['z_end'] - geometry[1]['z_start'])) * transmition + 
                  amplitude * np.exp(-z/z_att))

p_opt, p_cov = curve_fit(model_mu_t, e_Td[0], e_Td[1])

mu_t_0 = p_opt[0]
print('mu_t_0 = ',mu_t_0, ' mm-1')

plt.plot(e_Td[0], e_Td[1])
plt.plot(e_Td[0], model_mu_t(e_Td[0], *p_opt))
plt.show()
# Out:
# mu_t_0 =  14.01544180643701  mm-1

# %%
# start parameters

g_0 = 0.94
l_mu_t_0 = mu_t_0 * thickness[1]
l_mu_ss_0 = (mu_t_0 - 1) * (1-g_0) * thickness[1]
print('l_mu_t_0 = ',l_mu_t_0 , ', l_mu_ss_0 = ',l_mu_ss_0,', g_0 = ', g_0)

# error function
def error(x):
    l_mu_t, l_mu_ss, g = x[0], x[1], x[2]
    dz = (geometry[1]['z_end'] - geometry[1]['z_start'])
    mu_s = l_mu_ss / (1 - g) / dz
    mu_a = l_mu_t / dz - mu_s
    
    geometry[1]['g'] = g
    geometry[1]['mu_s'] = mu_s
    geometry[1]['mu_a'] = mu_a
    
    output_MIS = mlmc(parameters, geometry)
    
    print(mu_a, mu_s, g)
ionengine.py", line 171, in _raw_object_cache_notify
#     def _raw_object_cache_notify(self, data):
# KeyboardInterrupt:
# 1.5687146561420189 12.720551813109578 0.9376376507423846
# 0.008885600548389301
# 1.5687236921177856 12.720537639494141 0.9376375646507369
# 0.006673916110093795
# 1.568722010414552 12.720532202114512 0.937637537872482
# 0.006041591429803814
# 1.5687225024381526 12.720527455880454 0.9376375173484617
# 0.007184042125385528
# 1.5687332833711523 12.720509009707936 0.9376373908040191
# 0.01010806942713255
# 1.568719312982756 12.720541112225712 0.9376375857577932
# 0.009017524971457972
# 1.568724108639092 12.720526797302961 0.9376374988344343
# 0.008652235398527304
# 1.5687228512667417 12.720534920803756 0.9376375512616095
# 0.008609841217398422
# 1.5687183332871584 12.720542007603171 0.9376375943074333
# 0.007362049291406604
# 1.5687180213239476 12.720545956393924 0.9376376234599155
# 0.007890908609993445
# 1.5687160587513738 12.720545189936304 0.9376376191649443
# 0.00752866253800256
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [102], in <cell line: 1>()
# ----> 1 res = minimize(error, [l_mu_t_0, l_mu_ss_0, g_0], method='nelder-mead', options={'xatol': 1e-8, 'disp': True})
#
# File D:\Programm\Anaconda\lib\site-packages\scipy\optimize\_minimize.py:611, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     608     constraints = standardize_constraints(constraints, x0, meth)
#     610 if meth == 'nelder-mead':
# --> 611     return _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     612                                 **options)
#     613 elif meth == 'powell':
#     614     return _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File D:\Programm\Anaconda\lib\site-packages\scipy\optimize\optimize.py:768, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     766 if bounds is not None:
#     767     xr = np.clip(xr, lower_bound, upper_bound)
# --> 768 fxr = func(xr)
#     769 doshrink = 0
#     771 if fxr < fsim[0]:
#
# File D:\Programm\Anaconda\lib\site-packages\scipy\optimize\optimize.py:464, in _wrap_function.<locals>.function_wrapper(x, *wrapper_args)
#     462 def function_wrapper(x, *wrapper_args):
#     463     ncalls[0] += 1
# --> 464     return function(np.copy(x), *(wrapper_args + args))
#
# Input In [101], in error(x)
#      16 geometry[1]['mu_s'] = mu_s
#      17 geometry[1]['mu_a'] = mu_a
# ---> 19 output_MIS = mlmc(parameters, geometry)
#      21 print(mu_a, mu_s, g)
#      22 err = np.sum((np.log10(output_MIS['radiation_output'][1]) - np.log10(e_Td[1]))**2)
#
# File D:\Work\Programming\Jupyter Notebooks\Photonics Models\MC\IMCML_NK_v1.0\MCML.py:357, in mlmc(parameters, geometry)
#     354             p = turn(p, g_table[int(p[-1])])
#     355     return radiation_output, absorbtion_output
# --> 357 radiation_output, absorbtion_output = mlms_run(N, generator_distribution,
#     358             z_start_table, z_end_table, n_table, mu_a_table, mu_s_table, g_table,
#     359             radiation_output, absorbtion_output)
#     361 # forming output data
#     362 if parameters['radiation_saving_mode'] == 'FIS':
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\dispatcher.py:420, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     418 return_val = None
#     419 try:
# --> 420     return_val = self.compile(tuple(argtypes))
#     421 except errors.ForceLiteralArg as e:
#     422     # Received request for compiler re-entry with the list of arguments
#     423     # indicated by e.requested_args.
#     424     # First, check if any of these args are already Literal-ized
#     425     already_lit_pos = [i for i in e.requested_args
#     426                        if isinstance(args[i], types.Literal)]
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\dispatcher.py:965, in Dispatcher.compile(self, sig)
#     963 with ev.trigger_event("numba:compile", data=ev_details):
#     964     try:
# --> 965         cres = self._compiler.compile(args, return_type)
#     966     except errors.ForceLiteralArg as e:
#     967         def folded(args, kws):
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\dispatcher.py:125, in _FunctionCompiler.compile(self, args, return_type)
#     124 def compile(self, args, return_type):
# --> 125     status, retval = self._compile_cached(args, return_type)
#     126     if status:
#     127         return retval
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\dispatcher.py:139, in _FunctionCompiler._compile_cached(self, args, return_type)
#     136     pass
#     138 try:
# --> 139     retval = self._compile_core(args, return_type)
#     140 except errors.TypingError as e:
#     141     self._failed_cache[key] = e
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\dispatcher.py:152, in _FunctionCompiler._compile_core(self, args, return_type)
#     149 flags = self._customize_flags(flags)
#     151 impl = self._get_implementation(args, {})
# --> 152 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     153                               self.targetdescr.target_context,
#     154                               impl,
#     155                               args=args, return_type=return_type,
#     156                               flags=flags, locals=self.locals,
#     157                               pipeline_class=self.pipeline_class)
#     158 # Check typing error if object mode is used
#     159 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler.py:693, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     669 """Compiler entry point
#     670
#     671 Parameter
#    (...)
#     689     compiler pipeline
#     690 """
#     691 pipeline = pipeline_class(typingctx, targetctx, library,
#     692                           args, return_type, flags, locals)
# --> 693 return pipeline.compile_extra(func)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler.py:429, in CompilerBase.compile_extra(self, func)
#     427 self.state.lifted = ()
#     428 self.state.lifted_from = None
# --> 429 return self._compile_bytecode()
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler.py:497, in CompilerBase._compile_bytecode(self)
#     493 """
#     494 Populate and run pipeline for bytecode input
#     495 """
#     496 assert self.state.func_ir is None
# --> 497 return self._compile_core()
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler.py:463, in CompilerBase._compile_core(self)
#     461 res = None
#     462 try:
# --> 463     pm.run(self.state)
#     464     if self.state.cr is not None:
#     465         break
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler_machinery.py:341, in PassManager.run(self, state)
#     339 pass_inst = _pass_registry.get(pss).pass_inst
#     340 if isinstance(pass_inst, CompilerPass):
# --> 341     self._runPass(idx, pass_inst, state)
#     342 else:
#     343     raise BaseException("Legacy pass in use")
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler_machinery.py:296, in PassManager._runPass(self, index, pss, internal_state)
#     294     mutated |= check(pss.run_initialization, internal_state)
#     295 with SimpleTimer() as pass_time:
# --> 296     mutated |= check(pss.run_pass, internal_state)
#     297 with SimpleTimer() as finalize_time:
#     298     mutated |= check(pss.run_finalizer, internal_state)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler_machinery.py:269, in PassManager._runPass.<locals>.check(func, compiler_state)
#     268 def check(func, compiler_state):
# --> 269     mangled = func(compiler_state)
#     270     if mangled not in (True, False):
#     271         msg = ("CompilerPass implementations should return True/False. "
#     272                "CompilerPass with name '%s' did not.")
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\typed_passes.py:105, in BaseTypeInference.run_pass(self, state)
#      99 """
#     100 Type inference and legalization
#     101 """
#     102 with fallback_context(state, 'Function "%s" failed type inference'
#     103                       % (state.func_id.func_name,)):
#     104     # Type inference
# --> 105     typemap, return_type, calltypes, errs = type_inference_stage(
#     106         state.typingctx,
#     107         state.targetctx,
#     108         state.func_ir,
#     109         state.args,
#     110         state.return_type,
#     111         state.locals,
#     112         raise_errors=self._raise_errors)
#     113     state.typemap = typemap
#     114     # save errors in case of partial typing
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\typed_passes.py:83, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      81     infer.build_constraint()
#      82     # return errors in case of partial typing
# ---> 83     errs = infer.propagate(raise_errors=raise_errors)
#      84     typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      86 # Output all Numba warnings
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\typeinfer.py:1078, in TypeInferer.propagate(self, raise_errors)
#    1075 oldtoken = newtoken
#    1076 # Errors can appear when the type set is incomplete; only
#    1077 # raise them when there is no progress anymore.
# -> 1078 errors = self.constraints.propagate(self)
#    1079 newtoken = self.get_state_token()
#    1080 self.debug.propagate_finished()
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\typeinfer.py:155, in ConstraintNetwork.propagate(self, typeinfer)
#     152 with typeinfer.warnings.catch_warnings(filename=loc.filename,
#     153                                        lineno=loc.line):
#     154     try:
# --> 155         constraint(typeinfer)
#     156     except ForceLiteralArg as e:
#     157         errors.append(e)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\typeinfer.py:578, in CallConstraint.__call__(self, typeinfer)
#     576     fnty = typevars[self.func].getone()
#     577 with new_error_context("resolving callee type: {0}", fnty):
# --> 578     self.resolve(typeinfer, typevars, fnty)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\typeinfer.py:601, in CallConstraint.resolve(self, typeinfer, typevars, fnty)
#     599     fnty = fnty.instance_type
#     600 try:
# --> 601     sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     602 except ForceLiteralArg as e:
#     603     # Adjust for bound methods
#     604     folding_args = ((fnty.this,) + tuple(self.args)
#     605                     if isinstance(fnty, types.BoundFunction)
#     606                     else self.args)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\typeinfer.py:1555, in TypeInferer.resolve_call(self, fnty, pos_args, kw_args)
#    1552     return sig
#    1553 else:
#    1554     # Normal non-recursive call
# -> 1555     return self.context.resolve_function_type(fnty, pos_args, kw_args)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\typing\context.py:196, in BaseContext.resolve_function_type(self, func, args, kws)
#     194 # Prefer user definition first
#     195 try:
# --> 196     res = self._resolve_user_function_type(func, args, kws)
#     197 except errors.TypingError as e:
#     198     # Capture any typing error
#     199     last_exception = e
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\typing\context.py:248, in BaseContext._resolve_user_function_type(self, func, args, kws, literals)
#     244         return self.resolve_function_type(func_type, args, kws)
#     246 if isinstance(func, types.Callable):
#     247     # XXX fold this into the __call__ attribute logic?
# --> 248     return func.get_call_type(self, args, kws)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\types\functions.py:541, in Dispatcher.get_call_type(self, context, args, kws)
#     534 def get_call_type(self, context, args, kws):
#     535     """
#     536     Resolve a call to this dispatcher using the given argument types.
#     537     A signature returned and it is ensured that a compiled specialization
#     538     is available for it.
#     539     """
#     540     template, pysig, args, kws = \
# --> 541         self.dispatcher.get_call_template(args, kws)
#     542     sig = template(context).apply(args, kws)
#     543     if sig:
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\dispatcher.py:363, in _DispatcherBase.get_call_template(self, args, kws)
#     361 # Ensure an overload is available
#     362 if self._can_compile:
# --> 363     self.compile(tuple(args))
#     365 # Create function type for typing
#     366 func_name = self.py_func.__name__
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\dispatcher.py:965, in Dispatcher.compile(self, sig)
#     963 with ev.trigger_event("numba:compile", data=ev_details):
#     964     try:
# --> 965         cres = self._compiler.compile(args, return_type)
#     966     except errors.ForceLiteralArg as e:
#     967         def folded(args, kws):
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\dispatcher.py:125, in _FunctionCompiler.compile(self, args, return_type)
#     124 def compile(self, args, return_type):
# --> 125     status, retval = self._compile_cached(args, return_type)
#     126     if status:
#     127         return retval
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\dispatcher.py:139, in _FunctionCompiler._compile_cached(self, args, return_type)
#     136     pass
#     138 try:
# --> 139     retval = self._compile_core(args, return_type)
#     140 except errors.TypingError as e:
#     141     self._failed_cache[key] = e
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\dispatcher.py:152, in _FunctionCompiler._compile_core(self, args, return_type)
#     149 flags = self._customize_flags(flags)
#     151 impl = self._get_implementation(args, {})
# --> 152 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     153                               self.targetdescr.target_context,
#     154                               impl,
#     155                               args=args, return_type=return_type,
#     156                               flags=flags, locals=self.locals,
#     157                               pipeline_class=self.pipeline_class)
#     158 # Check typing error if object mode is used
#     159 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler.py:693, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     669 """Compiler entry point
#     670
#     671 Parameter
#    (...)
#     689     compiler pipeline
#     690 """
#     691 pipeline = pipeline_class(typingctx, targetctx, library,
#     692                           args, return_type, flags, locals)
# --> 693 return pipeline.compile_extra(func)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler.py:429, in CompilerBase.compile_extra(self, func)
#     427 self.state.lifted = ()
#     428 self.state.lifted_from = None
# --> 429 return self._compile_bytecode()
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler.py:497, in CompilerBase._compile_bytecode(self)
#     493 """
#     494 Populate and run pipeline for bytecode input
#     495 """
#     496 assert self.state.func_ir is None
# --> 497 return self._compile_core()
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler.py:463, in CompilerBase._compile_core(self)
#     461 res = None
#     462 try:
# --> 463     pm.run(self.state)
#     464     if self.state.cr is not None:
#     465         break
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler_machinery.py:341, in PassManager.run(self, state)
#     339 pass_inst = _pass_registry.get(pss).pass_inst
#     340 if isinstance(pass_inst, CompilerPass):
# --> 341     self._runPass(idx, pass_inst, state)
#     342 else:
#     343     raise BaseException("Legacy pass in use")
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler_machinery.py:296, in PassManager._runPass(self, index, pss, internal_state)
#     294     mutated |= check(pss.run_initialization, internal_state)
#     295 with SimpleTimer() as pass_time:
# --> 296     mutated |= check(pss.run_pass, internal_state)
#     297 with SimpleTimer() as finalize_time:
#     298     mutated |= check(pss.run_finalizer, internal_state)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\compiler_machinery.py:269, in PassManager._runPass.<locals>.check(func, compiler_state)
#     268 def check(func, compiler_state):
# --> 269     mangled = func(compiler_state)
#     270     if mangled not in (True, False):
#     271         msg = ("CompilerPass implementations should return True/False. "
#     272                "CompilerPass with name '%s' did not.")
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\typed_passes.py:394, in NativeLowering.run_pass(self, state)
#     391 with targetctx.push_code_library(library):
#     392     lower = lowering.Lower(targetctx, library, fndesc, interp,
#     393                            metadata=metadata)
# --> 394     lower.lower()
#     395     if not flags.no_cpython_wrapper:
#     396         lower.create_cpython_wrapper(flags.release_gil)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\lowering.py:196, in BaseLower.lower(self)
#     194 if self.generator_info is None:
#     195     self.genlower = None
# --> 196     self.lower_normal_function(self.fndesc)
#     197 else:
#     198     self.genlower = self.GeneratorLower(self)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\lowering.py:250, in BaseLower.lower_normal_function(self, fndesc)
#     248 # Init argument values
#     249 self.extract_function_arguments()
# --> 250 entry_block_tail = self.lower_function_body()
#     252 # Close tail of entry block, do not emit debug metadata else the
#     253 # unconditional jump gets associated with the metadata from the function
#     254 # body end.
#     255 with debuginfo.suspend_emission(self.builder):
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\lowering.py:279, in BaseLower.lower_function_body(self)
#     277     bb = self.blkmap[offset]
#     278     self.builder.position_at_end(bb)
# --> 279     self.lower_block(block)
#     280 self.post_lower()
#     281 return entry_block_tail
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\lowering.py:293, in BaseLower.lower_block(self, block)
#     290     defaulterrcls = partial(LoweringError, loc=self.loc)
#     291     with new_error_context('lowering "{inst}" at {loc}', inst=inst,
#     292                            loc=self.loc, errcls_=defaulterrcls):
# --> 293         self.lower_inst(inst)
#     294 self.post_block(block)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\lowering.py:438, in Lower.lower_inst(self, inst)
#     436 if isinstance(inst, ir.Assign):
#     437     ty = self.typeof(inst.target.name)
# --> 438     val = self.lower_assign(ty, inst)
#     439     argidx = None
#     440     # If this is a store from an arg, like x = arg.x then tell debuginfo
#     441     # that this is the arg
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\lowering.py:624, in Lower.lower_assign(self, ty, inst)
#     621     return res
#     623 elif isinstance(value, ir.Expr):
# --> 624     return self.lower_expr(ty, value)
#     626 elif isinstance(value, ir.Var):
#     627     val = self.loadvar(value.name)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\lowering.py:1135, in Lower.lower_expr(self, resty, expr)
#    1133 def lower_expr(self, resty, expr):
#    1134     if expr.op == 'binop':
# -> 1135         return self.lower_binop(resty, expr, expr.fn)
#    1136     elif expr.op == 'inplace_binop':
#    1137         lty = self.typeof(expr.lhs.name)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\lowering.py:694, in Lower.lower_binop(self, resty, expr, op)
#     690 def lower_binop(self, resty, expr, op):
#     691     # if op in utils.OPERATORS_TO_BUILTINS:
#     692     # map operator.the_op => the corresponding types.Function()
#     693     # TODO: is this looks dodgy ...
# --> 694     op = self.context.typing_context.resolve_value_type(op)
#     696     lhs = expr.lhs
#     697     rhs = expr.rhs
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\typing\context.py:381, in BaseContext.resolve_value_type(self, val)
#     375 """
#     376 Return the numba type of a Python value that is being used
#     377 as a runtime constant.
#     378 ValueError is raised for unsupported types.
#     379 """
#     380 try:
# --> 381     ty = typeof(val, Purpose.constant)
#     382 except ValueError as e:
#     383     # Make sure the exception doesn't hold a reference to the user
#     384     # value.
#     385     typeof_exc = utils.erase_traceback(e)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\typing\typeof.py:33, in typeof(val, purpose)
#      31 ty = typeof_impl(val, c)
#      32 if ty is None:
# ---> 33     msg = _termcolor.errmsg(
#      34         f"Cannot determine Numba type of {type(val)}")
#      35     raise ValueError(msg)
#      36 return ty
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\errors.py:317, in HighlightColorScheme.errmsg(self, msg)
#     316 def errmsg(self, msg):
# --> 317     return self._markup(msg, self._errmsg)
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\errors.py:307, in HighlightColorScheme._markup(self, msg, color, style)
#     305 if style:
#     306     features += style
# --> 307 with ColorShell():
#     308     with reset_terminal() as mu:
#     309         mu += features.encode('utf-8')
#
# File D:\Programm\Anaconda\lib\site-packages\numba\core\errors.py:225, in ColorShell.__init__(self)
#     224 def __init__(self):
# --> 225     init()
#     226     self._has_initialized = True
#
# File D:\Programm\Anaconda\lib\site-packages\colorama\initialise.py:38, in init(autoreset, convert, strip, wrap)
#      35     wrapped_stdout = None
#      36 else:
#      37     sys.stdout = wrapped_stdout = \
# ---> 38         wrap_stream(orig_stdout, convert, strip, autoreset, wrap)
#      39 if sys.stderr is None:
#      40     wrapped_stderr = None
#
# File D:\Programm\Anaconda\lib\site-packages\colorama\initialise.py:76, in wrap_stream(stream, convert, strip, autoreset, wrap)
#      74 def wrap_stream(stream, convert, strip, autoreset, wrap):
#      75     if wrap:
# ---> 76         wrapper = AnsiToWin32(stream,
#      77             convert=convert, strip=strip, autoreset=autoreset)
#      78         if wrapper.should_wrap():
#      79             stream = wrapper.stream
#
# File D:\Programm\Anaconda\lib\site-packages\colorama\ansitowin32.py:88, in AnsiToWin32.__init__(self, wrapped, convert, strip, autoreset)
#      83 on_windows = os.name == 'nt'
#      84 # We test if the WinAPI works, because even if we are on Windows
#      85 # we may be using a terminal that doesn't support the WinAPI
#      86 # (e.g. Cygwin Terminal). In this case it's up to the terminal
#      87 # to support the ANSI codes.
# ---> 88 conversion_supported = on_windows and winapi_test()
#      90 # should we strip ANSI sequences from our output?
#      91 if strip is None:
#
# File D:\Programm\Anaconda\lib\site-packages\colorama\win32.py:99, in winapi_test()
#      98 def winapi_test():
# ---> 99     return any(_winapi_test(h) for h in
#     100                (_GetStdHandle(STDOUT), _GetStdHandle(STDERR)))
#
# File D:\Programm\Anaconda\lib\site-packages\colorama\win32.py:99, in <genexpr>(.0)
#      98 def winapi_test():
# ---> 99     return any(_winapi_test(h) for h in
#     100                (_GetStdHandle(STDOUT), _GetStdHandle(STDERR)))
#
# File D:\Programm\Anaconda\lib\site-packages\colorama\win32.py:94, in _winapi_test(handle)
#      92 def _winapi_test(handle):
#      93     csbi = CONSOLE_SCREEN_BUFFER_INFO()
# ---> 94     success = _GetConsoleScreenBufferInfo(
#      95         handle, byref(csbi))
#      96     return bool(success)
#
# KeyboardInterrupt:
